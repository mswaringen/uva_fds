# %% [markdown]
# # Fundamentals of Data Science - Week 3 and Week 4

# %% [markdown]
# ###  <span style='color: green'>See Canvas croll down to the bottom of the notebook for assignment details</span>
# <p></p>
# <span style='color: red'>Deadline: 25/09/20, 23:59:59 </span>
#
#
# In this notebook we are going to cover the following practical aspects of data science:
#
# + Gathering data (scraping the Twitter Streaming API)
# + Storing and organizing it (store to file or a database)
# + Preprocess the data
# + Perform sentiment, topical and correlation analysis
# + Visualize
#
# To complete this assignment you need to have a running Anaconda installation with Python 3.8 on your device. Python package prerequisites include:
#
# +  **Twitter API Client** [Tweepy](https://github.com/tweepy/tweepy) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; [Install command: **pip install tweepy**]
# +  **Python Data Analysis Library** [Pandas](https://pandas.pydata.org/pandas-docs/stable/install.html)  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  [Install command: **pip install pandas**]
# +  **Python Visualization Library** [MatPlotLib](https://matplotlib.org/)   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; [Install command: **python -m pip install matplotlib**]
# +  **Python Topic Modelling Library** [GENSIM](https://radimrehurek.com/gensim/install.html) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  [Install command: **pip install --upgrade gensim**]
#
# An additional requirement if **you would like to use a database** is MongoDB (Community Server):
# + MongoDB database server instance [MongoDB Installation Instructions](https://docs.mongodb.com/manual/tutorial/install-mongodb-on-ubuntu/#install-mongodb-community-edition)
# + **Windows download** (and perhaps linux, untested): [link](https://www.mongodb.com/download-center?jmp=nav#community)
# +  **Python-Mongo Database Client** [PyMongo](https://api.mongodb.com/python/current/)  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  [Install command: **python -m pip install pymongo**]

# %% [markdown]
# ## Gathering Data - Twitter API
#
# The public Twitter API consists of a REST API and a Streaming API. Most application developers mix and match the APIs to produce their application. The Streaming API provides low-latency high-volume access to Tweets. Additionally, there are some families of APIs (such as the Ads API) which require your application to be whitelisted in order to make use of them. For this assignment we are going to use the [**Twitter Streaming API**](https://dev.twitter.com/streaming/overview).
#
# ### Twitter Streaming API
#
# The Streaming APIs give developers low latency access to Twitter’s global stream of Tweet data. A streaming client will be pushed messages indicating Tweets and other events have occurred, without any of the overhead associated with polling a REST endpoint.
#
# Twitter offers several basic streaming endpoints, each customized to certain use cases:
# + **Public Streams** - Streams of the public data flowing through Twitter. Suitable for following specific users or topics, and data mining.
# + **User Streams** &nbsp;&nbsp;&nbsp;- Single-user streams, containing roughly all of the data corresponding with a single user’s view of Twitter.
# + **Site Streams** &nbsp;&nbsp;&nbsp;&nbsp;- The multi-user version of user streams. Site streams are intended for servers which must connect to Twitter on behalf of many users. Site Streams is a closed beta. Applications are no longer being accepted.

# %% [markdown]
# In this assignment we are going to use the **Twitter Public Streams** to gather data about certain topics of interest. For using the Twitter API we need to create a Twitter Account, a Twitter APP and obtain the API Keys.
#
# ### Obtaining Twitter API Keys
#
# In order to access Twitter Streaming API, we need to get 4 pieces of information from Twitter: API key, API secret, Access token and Access token secret. Follow the steps below to get all 4 elements:
#
# + Create a twitter account if you do not already have one.
# + Go to https://apps.twitter.com/ and log in with your twitter credentials.
# + Click "Create New App"
# + Fill out the form, agree to the terms, and click "Create your Twitter application"
# + In the next page, click on "API keys" tab, and copy your "API key" and "API secret".
# + Scroll down and click "Create my access token", and copy your "Access token" and "Access token secret".
#
# ### Connecting to Twitter Streaming API and downloading data
#
# Now that we have the necessary credentials we can use the Tweepy library we installed in the previous step to connect to Twitter and start gathering data.
#
# First we import the required methods from the Tweepy library:

# %%
# Import the necessary methods from tweepy library

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %% [markdown]
# Next we copy the credentials in separate variables that we are going to use through the entire assignment.
#
# **NOTE** it is a general best practise not to keep sensitive data like API keys in a raw form in your scripts. For simplicity and demonstration purposes we can do that in this excercise, however this is not acceptible in a real live scenario.

# %%
consumer_key = 'TmjrH4cD4cG7RfoiN42wpGAwg'
consumer_secret = 'tfoOB4P3yx2XjCGXgzeOa5eQ70WBmEHTNA7Gld8RcwPECSaiHK'
access_token = '597732281-eYkrFH4gIQ67i9l2GzifdvKtc6Zxfyp7cgRxRPEr'
access_token_secret = 'n367uA0lexHNcfpBBmrTbNycYqcwjdnilDWdHLCJMUzl3'

# %% [markdown]
# Next we specify:
# + The location where we are going to dump the tweets that we obtained through the Streaming API
# + A basic function that formats and stores the tweets in a text file for later usage
# + A class consisting of a listener that attaches to a particular stream and displays the tweets directly onto the screen.

# %%
# We need to import json for dumping the tweets into our file
import json 

# Here we specify where the tweets would be stored
tweets_collection = 'tweets.txt'
tweet_file = open(tweets_collection, 'a')

#This a basic python function to append some value to a text file
def dump_tweet_to_json(tweet, dump_file):
     dump_file.write(tweet + '\n')
    
#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    # When we get data through the api print the data on screen
    def on_data(self, data):
        print(data)
        return (True)

    # When an error occures print the status code so that we know what it is.
    def on_error(self, status):
        print (status)

# %% [markdown]
# Using the defined class we can authenticate using the example below and attach our listener to a stream that is particularly interested in these topics:
# + Data Science
# + University Of Amsterdam
# + Python
# + Artificial Inteligence
#
# The code section below **will not stop automatically** once you run it (which is the whole point of the streaming API). To stop the execution and move on to the next section interupt the kernel using the **stop symbol** in the top toolbar.

# %% [markdown]
# #### Warning, you may have to restart the kernel to halt the stream depending on the Anaconda/tweepy version

# %%
if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API

    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    stream.filter(track=['data science', 'university of amsterdam', 'python', 'artificial intelligence'])
# Out:
# {"created_at":"Thu Sep 17 12:32:13 +0000 2020","id":1306571661777354752,"id_str":"1306571661777354752","text":"RT @VivaanChaudhar6: Gain advanced skills in analytics and transform your career. We at DataTrained provides hands on online Data Science t\u2026","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":802197583015841792,"id_str":"802197583015841792","name":"Nishant sharma","screen_name":"Nishant33962550","location":"Hyderabad, India","url":"http:\/\/www.pacteraedge.com","description":"Marketing Lead, INDIA\nPactera EDGE","translator_type":"none","protected":false,"verified":false,"followers_count":714,"friends_count":683,"listed_count":30,"favourites_count":15517,"statuses_count":18962,"created_at":"Fri Nov 25 17:09:42 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1260252198161637376\/LFbkZeuy_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1260252198161637376\/LFbkZeuy_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/802197583015841792\/1567754250","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Sep 17 11:32:41 +0000 2020","id":1306556678683459585,"id_str":"1306556678683459585","text":"Gain advanced skills in analytics and transform your career. We at DataTrained provides hands on online Data Scienc\u2026 https:\/\/t.co\/DmUzkVIRDp","display_text_range":[0,140],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1281168497456922624,"id_str":"1281168497456922624","name":"Vivaan Chaudhary","screen_name":"VivaanChaudhar6","location":null,"url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":6,"friends_count":37,"listed_count":0,"favourites_count":101,"statuses_count":100,"created_at":"Thu Jul 09 10:09:16 +0000 2020","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1281168598128635904\/P5P6T1YQ_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1281168598128635904\/P5P6T1YQ_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"Gain advanced skills in analytics and transform your career. We at DataTrained provides hands on online Data Science training in tools like R, Python, SAS, SQL, Big Data, Machine Learning with 100% placement or money back\n#datatrained #DataS ...
#
# {"created_at":"Thu Sep 17 12:32:15 +0000 2020","id":1306571667196444672,"id_str":"1306571667196444672","text":"RT @TrainingSadi: As added benefit, Delegates attending the Virtual Conference on Programming with Python for Executives and Decision Maker\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":740064647865241600,"id_str":"740064647865241600","name":"NISSI EMMANUEL","screen_name":"nissikolli","location":"Rajahmundry, India","url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":4,"friends_count":29,"listed_count":0,"favourites_count":8,"statuses_count":97,"created_at":"Tue Jun 07 06:15:36 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/740065572407234561\/ZK6-eZwk_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/740065572407234561\/ZK6-eZwk_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Sep 16 08:27:19 +0000 2020","id":1306147643140321285,"id_str":"1306147643140321285","text":"As added benefit, Delegates attending the Virtual Conference on Programming with Python for Executives and Decision\u2026 https:\/\/t.co\/XjZsch8khb","display_text_range":[0,140],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":1306146282466168832,"in_reply_to_status_id_str":"1306146282466168832","in_reply_to_user_id":1151421028171747328,"in_reply_to_user_id_str":"1151421028171747328","in_reply_to_screen_name":"TrainingSadi","user":{"id":1151421028171747328,"id_str":"1151421028171747328","name":"SADI Training","screen_name":"TrainingSadi","location":"1157 Francis Baard, PTA, SA","url":"https:\/\/www.saditraining.com\/","description":"Official Twitter Account of Southern Africa Development Institute (SADI), a Professional Development Institute based in Pretoria, South Africa.","translator_type":"none","protected":false,"verified":false,"followers_count":279,"friends_count":1598,"listed_count":0,"favourites_count":287,"statuses_count":187,"created_at":"Wed Jul 17 09:19:00 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1151950812601565185\/utF4MgZe_normal.png","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1151950812601565185\/utF4MgZe_normal.png","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1151421028171747328\/1580377256","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"As added benefit, Delegates atten ...
# {"created_at":"Thu Sep 17 12:32:15 +0000 2020","id":1306571669054656513,"id_str":"1306571669054656513","text":"RT @cyberpredator01: Click on below link to read...\n\nhttps:\/\/t.co\/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie\u2026","source":"","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1291541489294749698,"id_str":"1291541489294749698","name":"INBot","screen_name":"INBot11","location":"System","url":null,"description":"Hi, I'm a bot that gives retweet\u2019s to relevant information about technology (and some other things the community posts).","translator_type":"none","protected":false,"verified":false,"followers_count":302,"friends_count":0,"listed_count":4,"favourites_count":11573,"statuses_count":58204,"created_at":"Fri Aug 07 01:07:51 +0000 2020","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/
default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Sep 15 22:19:56 +0000 2020","id":1305994790664916995,"id_str":"1305994790664916995","text":"\ud83d\udd2c K-Means Clustering. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #PyTorch #Python #RStats\u2026 https:\/\/t.co\/JV0SiKoHNB","display_text_range":[0,140],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1141410142937911296,"id_str":"1141410142937911296","name":"# Patricia #","screen_name":"patri_vaquero_","location":"Community of Madrid, Spain","url":"https:\/\/github.com\/PatriciaVaquero","description":"Data Science | Machine Learning | Analytics \ud83d\udcbb\n\n\u2022 Data Analytics Intern at Stratebi Business Solutions \u2022","translator_type":"none","protected":false,"verified":false,"followers_count":2028,"friends_count":583,"listed_count":38,"favourites_count":10699,"statuses_count":12075,"created_at":"Wed Jun 19 18:19:19 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1287830360450109441\/X2nJMkcz_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1287830360450109441\/X2nJMkcz_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1141410142937911296\/1586171036","default_profile":true,"default_profile_image":false,"following": ...
#
# {"created_at":"Thu Sep 17 12:32:18 +0000 2020","id":1306571681553670149,"id_str":"1306571681553670149","text":"C++ std::is_sorted with std::deque\nhttps:\/\/t.co\/Wojvl1OnnS\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus\u2026 https:\/\/t.co\/dSlY1Q66LD","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1148528293911465984,"id_str":"1148528293911465984","name":"cppsecrets.com","screen_name":"cppsecrets","location":null,"url":"http:\/\/www.cppsecrets.com","description":"A Professional Handbook for C++ and Python Engineers. \nBe an author @cppsecrets.com\nYour small contribution can make someone's life easier.","translator_type":"none","protected":false,"verified":false,"followers_count":223,"friends_count":388,"listed_count":0,"favourites_count":262,"statuses_count":4179,"created_at":"Tue Jul 09 09:44:18 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1252286609648541696\/qd8IW2Is_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1252286609648541696\/qd8IW2Is_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1148528293911465984\/1598508582","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"C++ std::is_sorted with std::deque\nhttps:\/\/t.co\/Wojvl1OnnS\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #coding #java #javascript #programmer #snake #developer #code #machinelearning #html #datascience #reptile #ballpython","display_text_range":[0,243],"entities":{"hashtags":[{"text":"Cppsecrets","indices":[60,71]},{"text":"cppsecrets","indices":[72,83]},{"text":"python3","indices":[84,92]},{"text":"python","indices":[93,100]},{"text":"cplusplus","indices":[101,111]},{"text":"programming","indices":[112,124]},{"text":"coding","indices":[125,132]},{"text":"java","indices":[133,138]},{"text":"javascript","indices":[139,150]},{"text":"programmer","indices":[151,162]},{"text":"snake","indices":[163,169]},{"text":"developer","indices":[170,180]},{"text":"code","indices":[181,186]},{"text":"machinelearning","indices":[187,203]},{"text":"html","indices":[204,209]},{"text":"datascience","indices":[210,222]},{"text":"reptile","indices":[223,231]},{"text":"ballpython","indices":[232,243]}],"urls":[{"url":"https:\/\/t.co\/Wojvl1OnnS","expanded_url":"https:\/\/cppsecrets.com\/users\/2531211151171149710656555564103109971051084699111109\/C00-stdissorted-with-stddeque.php","display_url":"cppsecrets.com\/users\/25312111\u2026","indices":[35,58]}],"user_mentions":[],"symbols":[]}},"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":
...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8447f1d63779> in <module>
#       8     stream = Stream(auth, l)
#       9
# ---> 10     stream.filter(track=['data science', 'university of amsterdam', 'python', 'artificial intelligence'])
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     486
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#     490         if self.length is not None:
#
# ~/anaconda3/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     581         try:
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#     585                     return total_bytes
#
# ~/anaconda3/lib/python3.8/http/client.py in _get_chunk_left(self)
#     549                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#     553                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     509     def _read_next_chunk_size(self):
#     510         # Read the next chunk size from the file
# --> 511         line = self.fp.readline(_MAXLINE + 1)
#     512         if len(line) > _MAXLINE:
#     513             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# If we now modify our Listener class to store the tweets to a file instead of printing it on screen, we would be able to use the tweets for our later analysis. You may need to create a 'data' folder - depending on the system you may need to create this manually or it will be automatic.

# %%
#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    # When we get data through the api print the data on screen
    def on_data(self, data):
        print ("Stored a new tweet.")
        dump_tweet_to_json(data, tweet_file)
        return True

    # When an error occures print the status code so that we know what it is.
    def on_error(self, status):
        print ("Error: ", status)

# %% [markdown]
# If we run the main section for a short period of time again and check the tweets.txt file in the data folder we will find the streamed tweets.

# %% [markdown]
# #### Warning, you may have to restart the kernel to halt the stream depending on the Anaconda/tweepy version

# %%
if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API

    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    stream.filter(track=['data science', 'amsterdam', 'python', 'artificial intelligence', 'netherlands'])
# Out:
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# ...
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# Stored a new tweet.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-393cf8ab52b0> in <module>
#       8     stream = Stream(auth, l)
#       9
# ---> 10     stream.filter(track=['data science', 'amsterdam', 'python', 'artificial intelligence', 'netherlands'])
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     486
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#     490         if self.length is not None:
#
# ~/anaconda3/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     581         try:
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#     585                     return total_bytes
#
# ~/anaconda3/lib/python3.8/http/client.py in _get_chunk_left(self)
#     549                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#     553                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     509     def _read_next_chunk_size(self):
#     510         # Read the next chunk size from the file
# --> 511         line = self.fp.readline(_MAXLINE + 1)
#     512         if len(line) > _MAXLINE:
#     513             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Optional MongoDB check

# %% [markdown]
# If MongoDB is installed on your device and a database named Twitter is created, the tweets can be stored as database entries using the following code:
#
# **Note**: If Mongo is not installed on your device it will yield an error Connection Refused exception (on Windows it could be 'actively refused'). You need to install MongoDB community server.

# %%
from pymongo import MongoClient

client = MongoClient()
db = client.test

db.twitter.insert_one({'sample':'tweet'})

# %% [markdown]
# The final line of the code would replace the **dump_tweet_to_json()** function call in the Listener class.

# %% [markdown]
# ## Preprocessing the data
#
# Assuming that our stream listener has been running for a while and we have gathered some tweets, our tweets.txt file has grown to contain quite a few tweets now. If we open the file and read it line by line, we can import the tweets as json objects in a list and see their contents:

# %%
#Pprint is 'pretty print', simply a print function that gives 'nicer' outputs than print
from pprint import pprint

tweets_data = []
tweets_file = open(tweets_collection, "r")

for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
        print ('Imported tweet created at:', tweet['created_at'])
        print ('Tweet content: \n', tweet['text'], '\n')
    except Exception as e:
        print (e)
        continue

print ('#############################################' )       
print ('We have gathered:',len(tweets_data), 'tweets.')
print ('#############################################' ) 

print ("Information contained in a single tweet: \n")
pprint(tweets_data[0].keys())
# Out:
# Imported tweet created at: Thu Sep 17 12:33:03 +0000 2020
# Tweet content:
#  #WO2 (20-05-1940 (Opname)) Het koffiehuis, Amsterdam. https://t.co/DJwmf1lAeU NIOD: https://t.co/yq1Gm4VfVt
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:06 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:06 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:08 +0000 2020
# Tweet content:
#  RT @TruthSeeker____: Footage Of Biden Touching Girls On C-Span Flagged As Child Sexual Exploitation By By Twitter's Artificial Intelligence…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:09 +0000 2020
# Tweet content:
#  @SaleemKhanSafi
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:11 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:13 +0000 2020
# Tweet content:
#  Greetings from the Left Coast!
#
# 20 years ago in Amsterdam, I discovered that you could order a Red Bull and Vodka c… https://t.co/nTMBSpvNFz
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:16 +0000 2020
# Tweet content:
#  RT @VivaanChaudhar6: Gain advanced skills in analytics and transform your career. We at DataTrained provides hands on online Data Science t…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:17 +0000 2020
# Tweet content:
#  RT @RonLiOfficial: Code should talk
# .
# .
# Follow us on Instagram: https://t.co/dmdTTYHdCz
# .
# .
# #100daysofcode #codenewbie #developer #programm…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:17 +0000 2020
# Tweet content:
#  RT @_nasch_: Aprobado en tiempo récord y mi regalo para ustedes, gratis por tan sólo 3 días mi curso: Python sin fronteras. https://t.co/8w…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:18 +0000 2020
# Tweet content:
#  RT @ErrikB: Gisteren sprak wethouder @mvdoorninck de eerste Van der Vlislezing uit. Terugkijken naar de jaren 80 en vooruitblikken op hoe A…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:20 +0000 2020
# Tweet content:
#  Is there not anyone in the Chicago media willing to do their job? @GovPritzker is destroying businesses, preventing… https://t.co/NbzmDKjps0
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:21 +0000 2020
# Tweet content:
#  RT @sofiesyarief: HAHAHAHA https://t.co/q7NY8cyWRA
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:21 +0000 2020
# Tweet content:
#  @WebReflection Already done by Haxe. It's ECMAScript-based language + optionally ADT, pattern matching, decorators… https://t.co/chaDv8JyDA
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:22 +0000 2020
# Tweet content:
#  RT @llanga: #Python 3.9.0 is almost ready! The final preview release, RC2, is now available. Get it here:
#
# https://t.co/Lyo50dqKdi
#
# As ever…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:23 +0000 2020
# Tweet content:
#  RT @course_net: #MachineLearning
# Testing and Monitoring Machine Learning Model Deployments | Course
#
# =&gt; https://t.co/ES3oeNwHFa
#
# #DataSci…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:24 +0000 2020
# Tweet content:
#  @JoostSchreurs @EliannevT Ja, dan had Jan Roos waarschijnlijk bij de foto de tekst 'de burgemeester van Amsterdam' geplaatst...
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:25 +0000 2020
# Tweet content:
#  B1 (medium care) 13152 Rit 82114 Amsterdam Oosterpark 1091AC OLVGO C3 ccu https://t.co/DYJxwk7eak #p2000
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:25 +0000 2020
# Tweet content:
#  RT @HMDatabase: #STMF updated&amp;revised ✅
# ➡️New country Northern Ireland
# ➡️Croatian data avail up to 2020
# ‼️Picks of excess #mortality in sum…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:26 +0000 2020
# Tweet content:
#  They need to tell us the % false positive rate, otherwise the data is meaningless. The fact they don’t means either… https://t.co/b6FIrzZw0Y
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:26 +0000 2020
# Tweet content:
#  RT @MaxGraey: @WebReflection Already done by Haxe. It's ECMAScript-based language + optionally ADT, pattern matching, decorators and reflec…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:27 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:27 +0000 2020
# Tweet content:
#  pythonのこと数ヶ月前のわたしは大好きだったけど、今のわたしは嫌いだぞ
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:28 +0000 2020
# Tweet content:
#  Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop… https://t.co/RoYMKeKGE9
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:29 +0000 2020
# Tweet content:
#  RT @pronoiai: One thing Rhea will be well educated on and that is where certain countries are in the world - geography lessons.
# #ArrestSSRK…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:30 +0000 2020
# Tweet content:
#  14:33:24 B1 (medium care) 13152 Rit 82114 Amsterdam Oosterpark 1091AC OLVGO C3 ccu
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:30 +0000 2020
# Tweet content:
#  RT @pythonbot_: Algorithms to Live By: The Computer Science of Human Decisions https://t.co/iA0GXqxDLV  #python #ad
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:30 +0000 2020
# Tweet content:
#  RT @course_net: #MachineLearning
# Testing and Monitoring Machine Learning Model Deployments | Course
#
# =&gt; https://t.co/ES3oeNwHFa
#
# #DataSci…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:31 +0000 2020
# Tweet content:
#  @hmaon @KevinCu13907262 @HomeGirl_Shelly @ConservBlue2020 You cannot pull a website from with old data from a googl… https://t.co/W4DoUZui0F
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:32 +0000 2020
# Tweet content:
#  (#3FBC77) as flight #ABLE13 at 698 ft heading north bound over Utrecht (The Netherlands). At: https://t.co/znD8UqeqKW
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:33 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:33 +0000 2020
# Tweet content:
#  @HamidMirPAK
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:33 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:33 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:34 +0000 2020
# Tweet content:
#  会社のPCにCUDAとcuDNN入れて、pythonでGPUコンピューティングしたろ！と思って空き時間にちゃちゃっと入れたは良いものの、肝心のcupyが動かず死亡。
#
# tensorflowはgpu認識しているみたいだし、この辺は気… https://t.co/F38F3qu0ls
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:34 +0000 2020
# Tweet content:
#  Overval op belwinkel Amsterdam-Oost https://t.co/33jyVJZSTu
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:34 +0000 2020
# Tweet content:
#  C++ std::is_sorted with std::list
# https://t.co/NMjli9gAab
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/ca3rWDesQU
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:35 +0000 2020
# Tweet content:
#  https://t.co/Gw3rcAACn1‘Bijnaiemand kan uitleggen wat data analytics toevoegt’Machine learning, artificial intellig… https://t.co/CmBeoctDon
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:36 +0000 2020
# Tweet content:
#  RT @PinakiLaskar: Life
#
# #ArtificialIntelligence #MachineLearning #BigData #DataScience #AI #IoT #Python #RStats #Java #JavaScript #ReactJS…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:36 +0000 2020
# Tweet content:
#  RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:36 +0000 2020
# Tweet content:
#  RT @asffofficial: ⚡️« La hija de un ladrón » (A thief’s daughter), a film by @_belenfunes_ , will officially premiere at the #SpanishFilmFe…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:38 +0000 2020
# Tweet content:
#  RT @falsel_net: Amsterdam   ❌❌❌
# Incidence #SARSCoV2 per 100k last 7 d   170,4
#
# Rotterdam
# Incidence #SARSCoV2 per 100k last 7 d   128,0…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:39 +0000 2020
# Tweet content:
#  @Marco_Langbroek What altitude for the stage is assumed here? I'm currently at 11°E 53°N, about twice as far from t… https://t.co/fEz9bxj5kK
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:39 +0000 2020
# Tweet content:
#  @mackflinx Amsterdam !
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:39 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ std::is_sorted with std::list
# https://t.co/NMjli9gAab
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus #programming…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:42 +0000 2020
# Tweet content:
#  RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:43 +0000 2020
# Tweet content:
#  @ParisDaguerre Nope he'll go on to make millions in Monty Python's Flying Circus
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:44 +0000 2020
# Tweet content:
#  RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:46 +0000 2020
# Tweet content:
#  RT @RightToLifeUK: The experience of the Netherlands should be a cautionary tale for countries debating assisted dying, @TheoBoer argues fo…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:46 +0000 2020
# Tweet content:
#  RT @MarioMonforte: Intel Core i9 is the best processor for creators, you can make a movie or an artwork. Brign your dreams to life, or crea…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:46 +0000 2020
# Tweet content:
#  @shazbkhanzdaGEO
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:46 +0000 2020
# Tweet content:
#  @Supremacy3rd @Roblox_RTC -new uploads by a specific creator. You can copy URLs and paste them in the dialog box. I… https://t.co/XUDsZxkjj4
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:48 +0000 2020
# Tweet content:
#  RT @Analytics_699: #AV get it's first tunnel loop ready in #LasVegas ▶️
#
# #Analytics #MachineLearning #AI #Python #javascript #TensorFlow
# #I…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:48 +0000 2020
# Tweet content:
#  RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:48 +0000 2020
# Tweet content:
#  RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:49 +0000 2020
# Tweet content:
#  Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop… https://t.co/e2iVLyoj9m
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:49 +0000 2020
# Tweet content:
#  RT @ryanstruyk: Confidence in President Trump in poll of 13 countries via
# @pewresearch:
#
# 25% Japan
# 23% Australia
# 20% Canada
# 19% United Kin…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:49 +0000 2020
# Tweet content:
#  RT @earthcurated: Amsterdam, Netherlands https://t.co/iU37txRL1d
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:51 +0000 2020
# Tweet content:
#  RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.
# Rotterdam-Amsterdam: 75 km, 45 minuts en tren
# Manresa-Barcelona: 60 km, 1h 30 en tren.
# Ut…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:51 +0000 2020
# Tweet content:
#  If you’re coming from other languages, e.g. #Python python, watch out when concatenating two arrays in #javascript.… https://t.co/KlbUr7sHDo
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:52 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:52 +0000 2020
# Tweet content:
#  The way there's actually a two-headed calf in a zoo run by a cult-ish group in Dumaguete... They had a python all t… https://t.co/puhoOgAgIb
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:52 +0000 2020
# Tweet content:
#  RT @steeph: Shit
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:53 +0000 2020
# Tweet content:
#  RT @JKDubai1: 🇵🇰🇦🇹🇦🇹🇵🇰
# PAK - AUSTRIA
#
# Today PM @ImranKhanPTI inaugurated Pak-Austria Fachhochschule Institute of Applied Sciences &amp; Technol…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:54 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:54 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:54 +0000 2020
# Tweet content:
#  RT @_nasch_: Aprobado en tiempo récord y mi regalo para ustedes, gratis por tan sólo 3 días mi curso: Python sin fronteras. https://t.co/8w…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:54 +0000 2020
# Tweet content:
#  【CV上坂すみれ】AI・機械学習入門第二弾！音声データから、声優を識別するAIを創る！
#  5秒で学習を始められる、Python×動画×オンライン実行環境によるAI入門者、機械学習入門者向けコンテンツです https://t.co/sJJh4kTPZN #声優識別AI
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:54 +0000 2020
# Tweet content:
#  Fisher 31
# € 36,900
# Country: Netherlands
# Year built: 1980
# LOA (m): 9.5
# Hull material: GRP
# Fuel: Diesel… https://t.co/hUOi1wHVxF
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:55 +0000 2020
# Tweet content:
#  RT @course_net: #MachineLearning
# Testing and Monitoring Machine Learning Model Deployments | Course
#
# =&gt; https://t.co/ES3oeNwHFa
#
# #DataSci…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:56 +0000 2020
# Tweet content:
#  @tancredipalmeri Tu sei stato ad Amsterdam sembra.... Ah no, per te é la normalità la disinformazione
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:57 +0000 2020
# Tweet content:
#  RT @hype4com: If you’re coming from other languages, e.g. #Python python, watch out when concatenating two arrays in #javascript. The resul…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:57 +0000 2020
# Tweet content:
#  @ScuderiaFerrari https://t.co/H4IfSv6kl0
# On Oct. 29, 2014, The Imperial Banquet was held at the Imperial Palace… https://t.co/UMEKc1qIgw
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:57 +0000 2020
# Tweet content:
#  RT @FootballOranje_: What are your thoughts on the likely appointment of Frank de Boer as Netherlands boss?
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:58 +0000 2020
# Tweet content:
#  RT @infomubashir: After witnessing #panther #bigcats &amp; #Deer on #Hyderabad city roads during #lockdown now city witnessed   #Python &amp; #Croc…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:59 +0000 2020
# Tweet content:
#  @Matiullahjan919
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:59 +0000 2020
# Tweet content:
#  RT @OneKindesign: Modern villa in Amsterdam offers fabulous indoor-outdoor connectivity https://t.co/sjJcXbvPts https://t.co/amMnXE0BFH
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:59 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:59 +0000 2020
# Tweet content:
#  RT @LindaBowmanL: What’s it going to take to change peoples minds ?  Logic, science, medicine it’s all there!!! Please make the right choic…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:33:59 +0000 2020
# Tweet content:
#  RT @Dr_MariamMatar: .
# صباحكم وطن يتباهى بأبناءه المخلصين في كل الميادين🇦🇪
# .
# الله يوفق لخير البلاد والعباد🌹 ألف مبروك د.سعيد الظاهري
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:00 +0000 2020
# Tweet content:
#  Phillip II joined Charles and outlawed Protestantism as well as sent the Inquisition to the Netherlands. The Inquis… https://t.co/0T00vI0Rwa
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:01 +0000 2020
# Tweet content:
#  @voorschot I’ve been to Noord Holland twice in the last week. The ticket even has been issued by Amsterdam Centraal… https://t.co/79YNv7ECHB
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:02 +0000 2020
# Tweet content:
#  RKI meldet neue Risikogebiete in Europa, Reisewarnungen folgen Wien und Amsterdam betroffen https://t.co/C5Hucszo0L https://t.co/Gy8FDwWUXd
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:03 +0000 2020
# Tweet content:
#  @realDonaldTrump Math, science, data analytics, human compassion... all concepts too hard for you and your Admin. SMDH.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:03 +0000 2020
# Tweet content:
#  RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:04 +0000 2020
# Tweet content:
#  Data Science and Engineering E-Degree (2020) Eduonix Coupons - https://t.co/V0HnbRrtOP
# -
#  #datascience #science
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:06 +0000 2020
# Tweet content:
#  C++ std::is_sorted with std::vector
# https://t.co/6XEBjJe6CU
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/LbhN974yXO
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:07 +0000 2020
# Tweet content:
#  RT @palazzo214: @RexChapman Yes, America is divided...on masks of all things. Which one are you?
#
# Team NO MASK: me me me American (ie. Trum…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:07 +0000 2020
# Tweet content:
#  Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop… https://t.co/lG4DCSCoaf
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:09 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:12 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ std::is_sorted with std::vector
# https://t.co/6XEBjJe6CU
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus #programmi…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:12 +0000 2020
# Tweet content:
#  RT @antgrasso: Getting the most out of Data Science is not impossible but it does require some knowledge.
#
# @OracleItalia has organized a fr…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:12 +0000 2020
# Tweet content:
#  RT @VincenzoSelXXX: Subscribe for more... 💦 drakes Amsterdam gloryhole!
#
# Whole 73 min video at:
# https://t.co/Dz6WJxxNj5
# https://t.co/nbyu…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:12 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ std::is_sorted with std::vector
# https://t.co/6XEBjJe6CU
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus #programmi…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:12 +0000 2020
# Tweet content:
#  RT @bajcmartinez: @DevShehu @_Thorby That's correct. They are not a very popular feature in JS compared to other languages like Python, but…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:13 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:13 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:13 +0000 2020
# Tweet content:
#  Artificial intelligence is changing SEO. Here's what you'll need to do to optimize for machine learning and termina… https://t.co/xjHPvGy7V1
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:13 +0000 2020
# Tweet content:
#  RT @RepsForBiden: The world is laughing at you @realDonaldTrump
# Unfortunately, we all pay the price.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:13 +0000 2020
# Tweet content:
#  First #ArtificialIntelligence gadgets for the home.
# @GeorgeWillems1 @BViseeon @SiddharthKS  @RLDI_Lamy @baski_LA… https://t.co/py8uia1cGg
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:15 +0000 2020
# Tweet content:
#  Video...Greece...Island...Lesbos...Police...Clear...Street...Migrant...overcrowd...Moria...facility...destroy...fir… https://t.co/CWjRbwQWM8
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:15 +0000 2020
# Tweet content:
#  RT @Entrepreneurix: Van #D66 wisten we het al, maar ook de #VVD-ers blijken gewoon #EU systeemclowns te zijn geworden.
#
# Waarom is de EU zo…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:16 +0000 2020
# Tweet content:
#  RT @BBWfan9: The heat is on in the netherlands today! https://t.co/PoY1WbmCfY
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:17 +0000 2020
# Tweet content:
#  RT @watherkiller: Il y a un 1 ans jour pour jour je vivais l un de mes meilleurs jour en tant que supporter du losc a Amsterdam et aujourd'…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:17 +0000 2020
# Tweet content:
#  学習498日目　1.0時間
# 累計：689.4時間
# 技術：Python
# プログラミング演習 Python2019 15Pまで読了
#  #TechCommit
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:19 +0000 2020
# Tweet content:
#  なんで今頃Pythonの勉強を始めたかってそりゃあなたAtCoderに参戦するためですよ
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:19 +0000 2020
# Tweet content:
#  RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.
# Rotterdam-Amsterdam: 75 km, 45 minuts en tren
# Manresa-Barcelona: 60 km, 1h 30 en tren.
# Ut…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:20 +0000 2020
# Tweet content:
#  RT @DevelopmentPk: PM Imran Khan inaugurated another flagship project of #KP Government, Pak-Austria Fachhochschule University, #Haripur. U…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:21 +0000 2020
# Tweet content:
#  Laura. Thank you for telling the truth and updated.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:22 +0000 2020
# Tweet content:
#  RT @glenannefilm: A huge rise in DVD requests internationally after last night’s screening. This batch posting to Australia, US, Netherland…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:22 +0000 2020
# Tweet content:
#  @peaceforchange
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:25 +0000 2020
# Tweet content:
#  RT @Entrepreneurix: https://t.co/iCp84jD95x
#
# Picture of #StefBlok and Joseph Borrell makes you understand why the Dutch Minister of Foreign…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:26 +0000 2020
# Tweet content:
#  RT @MIGOPChair: And this surprises ...anyone?Whitmer continues to HIDE 🤐 the "science and data" and ANY information concerning her deadly n…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:28 +0000 2020
# Tweet content:
#  Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop… https://t.co/yft70IWfi7
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:28 +0000 2020
# Tweet content:
#  RT @mygovindia: Are you an AI enthusiast and you think your innovative AI solution has the power to solve societal challenges? Then we have…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:30 +0000 2020
# Tweet content:
#  RT @s_kampakis: What Do Experts Say About the Future of #MachineLearning (and Python)? #AI #DataScience via @STXNext https://t.co/QuroAiA02Q
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:31 +0000 2020
# Tweet content:
#  RT @Datagraver: Update status #covid19 for the Netherlands
# https://t.co/2pd5WlSoJr
# 1753 cases, 6 fatalities, 14 hospitalizations reported t…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:31 +0000 2020
# Tweet content:
#  RT @KirkDBorne: What is Artificial Intelligence? Explained in 101 seconds by
# @GaryZero @Qualcomm [video]: https://t.co/YU5aeFTsuF
# —————
# #A…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:31 +0000 2020
# Tweet content:
#  RT @kylamb8: This isn't the killer of younger or healthier people that other viruses have been. But we knew that since median age dying is…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  @dracaryskz i wanted it but i just bought the standard bc it doesn't ship to the netherlands :(
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  United States Air Force Lockheed C-130H Hercules (95-6711, #ADFDD5) at 800 ft heading north bound over Utrecht (The… https://t.co/TM0Uuc3CZj
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @Locat1ons: Haarlem, Netherlands 🇳🇱
# via: amsterdamcanals https://t.co/Xkdt6AsqQN
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @DataScience_b: Role-playing dimensions in Power BI
# https://t.co/Z22KVlyvD5
#  #data #science #datascience
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @DataScience_b: Pandas has superpowers in reading Excel files
# https://t.co/0IakiU8lzs
#  #data #science #datascience
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @s_kampakis: What Do Experts Say About the Future of #MachineLearning (and Python)? #AI #DataScience via @STXNext https://t.co/QuroAiA02Q
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @ds_vault: Data Science and Engineering E-Degree (2020) Eduonix Coupons - https://t.co/V0HnbRrtOP
# -
#  #datascience #science
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @_Nitin__Rawat_: What is 3090 ? 😂
# #Coding #5G #applewatchseries6 #code #programming #AI #javascript30 #programfolback
# #100DaysOfCode #P…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @hype4com: If you’re coming from other languages, e.g. #Python python, watch out when concatenating two arrays in #javascript. The resul…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @DataScience_b: Modeling Topic Trends in FOMC Meetings
# https://t.co/KbF60YPvHp
#  #data #science #datascience
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @course_net: #MachineLearning
# Testing and Monitoring Machine Learning Model Deployments | Course
#
# =&gt; https://t.co/ES3oeNwHFa
#
# #DataSci…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @DataScience_b: How to Manage a Junior Data Scientist
# https://t.co/P3DkHT91Zq
#  #data #science #datascience
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @RonLiOfficial: Code should talk
# .
# .
# Follow us on Instagram: https://t.co/dmdTTYHdCz
# .
# .
# #100daysofcode #codenewbie #developer #programm…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @Courseverse: Master Complete Statistics For Computer Science - I ($94.99 to Free) #100DaysOfCode #DataScience #MachineLearning #IoT #Ja…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @works_delight: In what order do you have to learn web development?
#
# Html (10 days).....Css (10 days)
# Jquery(20 days).....Bootstrap( 20…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:32 +0000 2020
# Tweet content:
#  RT @antgrasso: Getting the most out of Data Science is not impossible but it does require some knowledge.
#
# @OracleItalia has organized a fr…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:33 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:33 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:33 +0000 2020
# Tweet content:
#  PropertyEU Netherlands Roundtable: distress looming as capital continues to chase core product… https://t.co/bHYYcr8GQ9
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:34 +0000 2020
# Tweet content:
#  Amsterdam, The Netherlands
#   It has gradually become the most multicultural and liberal city in the world. Amsterda… https://t.co/TRawkVVHiQ
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:37 +0000 2020
# Tweet content:
#  Michael Galarnyk, a skilled data science instructor, joins us to answer your questions about data science education… https://t.co/oz7vB2tSpC
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:38 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:39 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:39 +0000 2020
# Tweet content:
#  RT @acityinohio: almost all of cryptocurrency governance is an extended Monty Python sketch
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:39 +0000 2020
# Tweet content:
#  The military is working on game-changing technologies, such as artificial intelligence and 5G, and looks to move th… https://t.co/b77DVW10Jm
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:40 +0000 2020
# Tweet content:
#  RT @PythonInsider: Python 3.9.0rc2 is now available for testing https://t.co/wyLUn3Zyum
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:41 +0000 2020
# Tweet content:
#  C++ std::fill with std::array
# https://t.co/GjWIizORCd
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/0fXjFUAO8U
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:41 +0000 2020
# Tweet content:
#  @EliannevT Nee nu insinueer jij dat ik insinueer dat Jan kennis heeft. Dat terwijl iedereen wel kan nagaan dat Hals… https://t.co/lwX6AXbMIf
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:42 +0000 2020
# Tweet content:
#  RT @Ben_garrod: It doesn’t take much to make us academics happy ... you know what to do :)
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:44 +0000 2020
# Tweet content:
#  RT @AbdulBa54505576: #Android RecyclerView with #Kotlin https://t.co/eB29YC26yY
#
# #100DaysOfCode #JavaScript #CodeNewbie #Java #developer #A…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:44 +0000 2020
# Tweet content:
#  Imagine influencing so many with your science (and the charisma that accompanied it) ⭐️
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:45 +0000 2020
# Tweet content:
#  @RMConservative If a university closed campus &amp; sent kids home with no plan back in March based on faulty science/d… https://t.co/5rLyCIXsP8
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:46 +0000 2020
# Tweet content:
#  @Benazir_Shah
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:46 +0000 2020
# Tweet content:
#  RT @KimDotcom: The US govt operates massive data centers with the capacity to store all human communications for decades. The data is highl…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:47 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ std::fill with std::array
# https://t.co/GjWIizORCd
#
# #Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #co…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:47 +0000 2020
# Tweet content:
#  RT @rubenkoops: Burgemeester Halsema kondigt aan in gesprek gaat met de verhuurder van de megakerk Hillsong in Amsterdam, omdat dit een bro…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:48 +0000 2020
# Tweet content:
#  RT @glenannefilm: A huge rise in DVD requests internationally after last night’s screening. This batch posting to Australia, US, Netherland…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:48 +0000 2020
# Tweet content:
#  （実は…Pythonを「ファイトン」と読んでました😅
# 先日書店で本を見ているときに、ふりがなが振ってある本がありまして、「パイソン」と書いてありましてね…えぇ、一人で心の中で「恥ずかしー💦」ってなってました😅）
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:49 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:49 +0000 2020
# Tweet content:
#  @whitehawk1186 @GovNedLamont https://t.co/x3lCCMSY4y
#
# Wow you clearly don’t have basic understanding of how science… https://t.co/Ax17TxdswR
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:50 +0000 2020
# Tweet content:
#  RT @Datagraver: Update status #covid19 for the Netherlands
# https://t.co/2pd5WlSoJr
# 1753 cases, 6 fatalities, 14 hospitalizations reported t…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:50 +0000 2020
# Tweet content:
#  RT @Analyticsindiam: #Tutorial
# Holoviews is an #opensource #python library that makes #datavisualization easier.
# Read more here - https://t…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:51 +0000 2020
# Tweet content:
#  RT @JustinWolfers: Change in the unemployment rate since January:
# U.S.A. +4.8%
# Canada +4.7%
# Australia +2.2%
# Spain +2.0%
# Sweden +2.0%
# Mexico…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:52 +0000 2020
# Tweet content:
#  RT @gvanrossum: [Repeat so more people are aware of this]
# Python 4 FAQ.
# 1. The version after 3.9 is 3.10; in fact it already exists (in git…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:52 +0000 2020
# Tweet content:
#  RT @BTS_twt: Amsterdam 1/2 😲 with쩨이홉 https://t.co/QEzqkiPYUr
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:53 +0000 2020
# Tweet content:
#  RT @JustinWolfers: Change in the unemployment rate since January:
# U.S.A. +4.8%
# Canada +4.7%
# Australia +2.2%
# Spain +2.0%
# Sweden +2.0%
# Mexico…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:53 +0000 2020
# Tweet content:
#  RT @btsdutchstats: Spotify Netherlands 🇳🇱
#
# #29 (+3) *new peak* ‘Dynamite’ 95,160 🔼
#
# Total: 1,904,011
#
# @BTS_twt https://t.co/Ab4FZvmbpj
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:54 +0000 2020
# Tweet content:
#  RT @gp_pulipaka: The Essential Amazon #AWS Books for Cloud Professionals. #BigData #Analytics #DataScience #IoT #IIoT #Python #RStats #Tens…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:54 +0000 2020
# Tweet content:
#  Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop… https://t.co/PqrEEgCffV
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:55 +0000 2020
# Tweet content:
#  @banaanpankoek @turtlejoestin Jaa preciess self made brands! Ik ken en paar van jonge ondernemers in amsterdam en z… https://t.co/wRvLaqokGo
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:55 +0000 2020
# Tweet content:
#  @willzknight @bicycal_life @AnnChivers2 @Chris_Boardman It's not when it adds one extra thing to what you have to c… https://t.co/xiChLbhgjU
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:56 +0000 2020
# Tweet content:
#  RT @ianmSC: Holy cow. This is unbelievable.
#
# The science and data is overwhelming tonight. https://t.co/BXucVQmk2b
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:56 +0000 2020
# Tweet content:
#  RT @hope_ssr: NCB got leads that Prime accused Rhea used to order drugs from outside India, Especially from Netherlands #ArrestSSRKillersNow
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:56 +0000 2020
# Tweet content:
#  &gt;&gt;&gt;---&gt;@GovInslee #MaggotJay
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:34:57 +0000 2020
# Tweet content:
#  It's obvious - "1,2,34,5,6"
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:00 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:00 +0000 2020
# Tweet content:
#  RT @cyberpredator01: Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop #computerscie…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:00 +0000 2020
# Tweet content:
#  RT @ShellenbergerMD: For decades everybody thought nuclear energy was dead in the Netherlands
#
# But now, the government is seriously explori…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:00 +0000 2020
# Tweet content:
#  #AUS #entrepreneur #techcomm Have you heard of #ArtificialIntelligence #AI for app &amp; websites? We can show you the… https://t.co/qKbA5OJYrX
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:00 +0000 2020
# Tweet content:
#  RT @malkusm: Now a whole lot of people know what I've known about the situation in Nashville for weeks.
#
# Not only is our COVID policy not d…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:00 +0000 2020
# Tweet content:
#  @AmberRShamsi
# https://t.co/E4GiDnzg96 - admin
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:01 +0000 2020
# Tweet content:
#  Nice.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:02 +0000 2020
# Tweet content:
#  RT @olgatuleninova: "Peasant Woman Binding Sheaves".(1889)
# By Vincent van Gogh.Dutch post-impressionist
# Van Gogh Museum. Amsterdam https://…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:03 +0000 2020
# Tweet content:
#  RT @s_adamiak: It's obvious - "1,2,34,5,6" https://t.co/UUSKQIXHOJ
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:03 +0000 2020
# Tweet content:
#  RT @MicrosoftUK: It's National Coding Week here in the UK!
#
# Whether you are a C# student or a Python pro, it's never too late to brush up…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:05 +0000 2020
# Tweet content:
#  RT @mygovindia: Are you an AI enthusiast and you think your innovative AI solution has the power to solve societal challenges? Then we have…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:05 +0000 2020
# Tweet content:
#  RT @NL_Times: Netherlands' Covid testing system not ready for second wave, Inspectorate says https://t.co/L5bQa7HjXP
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:08 +0000 2020
# Tweet content:
#  RT @BTS_twt: Amsterdam 2/2 📸🤨 https://t.co/63iq5qvSXl
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:09 +0000 2020
# Tweet content:
#  @BitcoinBiology @_jonasschnelli_ @BitcoinAustrian Science is also about observing, collecting data, and interpretin… https://t.co/L7N02ZaON7
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:10 +0000 2020
# Tweet content:
#  RT @Datagraver: Update status #covid19 for the Netherlands
# https://t.co/2pd5WlSoJr
# 1753 cases, 6 fatalities, 14 hospitalizations reported t…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:10 +0000 2020
# Tweet content:
#  A Place of Refuge: Rome and Amsterdam | Al Jazeera World https://t.co/P0KKd3YCFt
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:11 +0000 2020
# Tweet content:
#  @meckimac @elonmusk @ID_AA_Carmack @lexfridman Just Heard, only available in switzerland, Norway and netherlands. A… https://t.co/FXPCENMKnm
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:12 +0000 2020
# Tweet content:
#  RT @course_net: #MachineLearning
# Testing and Monitoring Machine Learning Model Deployments | Course
#
# =&gt; https://t.co/ES3oeNwHFa
#
# #DataSci…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:12 +0000 2020
# Tweet content:
#  RT @ZRAFC: Bayern has already agreed a five-year contract with Barca target Sergino Dest and negotiations with Ajax Amsterdam have intensif…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:14 +0000 2020
# Tweet content:
#  RT @contempediacom: #development
# Master Laravel with GraphQL, Vue.js and Tailwind | Course =&gt; https://t.co/SPbpdW8GrK
#
# #100DaysOfCode #ude…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:14 +0000 2020
# Tweet content:
#  Click on below link to read...
#
# https://t.co/R8733RsYt8
#
# #computer #technology #pc #tech #gaming #laptop… https://t.co/0gVUCm0MBZ
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:15 +0000 2020
# Tweet content:
#  RT @gp_pulipaka: The Essential Amazon #AWS Books for Cloud Professionals. #BigData #Analytics #DataScience #IoT #IIoT #Python #RStats #Tens…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 12:35:15 +0000 2020
# Tweet content:
#  RT @RitupaGhosh: First #ArtificialIntelligence gadgets for the home.
# @GeorgeWillems1 @BViseeon @SiddharthKS  @RLDI_Lamy @baski_LA @Nicochan…
#
# Expecting value: line 2 column 1 (char 1)
# ...
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:28:59 +0000 2020
# Tweet content:
#  RT @st0rmdriven: Just found out they dont sell goldfish crackers in the Netherlands. I hate this.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:00 +0000 2020
# Tweet content:
#  RT @o_gabsferreira: Animação de rotação feita em Python https://t.co/tQ0X7EZOjQ
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:01 +0000 2020
# Tweet content:
#  RT @ctrabado1: 🔙 Kit de survie #Python en #seconde &amp; #première
# ➡https://t.co/TPc9W9amk7
#
# 👉Des ressources issues de l’atelier "langage de p…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:03 +0000 2020
# Tweet content:
#  @frsvrt @ContainmentNu Kijk naar de reactie van de burgemeester van Delft op de tweet van @gertvdijk op 5 sept. Gee… https://t.co/Wxm3CwMHji
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:04 +0000 2020
# Tweet content:
#  RT @mattmayo13: Implementing a Deep Learning Library from Scratch in Python - KDnuggets https://t.co/2SdqeYxydS https://t.co/MiifS0mA9x
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:05 +0000 2020
# Tweet content:
#  How to implement Linear Regression with TensorFlow #ArtificialIntelligence via https://t.co/bDTgBUrl56 https://t.co/OoIrwYqXF5
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:05 +0000 2020
# Tweet content:
#  Unbelievable Influence of Artificial Intelligence on Social Media #SocialMedia via https://t.co/YRJVTPKreC https://t.co/29n2g86cAU
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:05 +0000 2020
# Tweet content:
#  RT @OntTory: The framing of lockdowns as inevitable or 'the only option' is outrageous - defies all science and data. https://t.co/3FEnFflX…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:06 +0000 2020
# Tweet content:
#  @prodnose @quantick @Tim_Burgess Has anyone mentioned Monty Python yet?
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:06 +0000 2020
# Tweet content:
#  @AnnChivers2 @Chris_Boardman In my opinion helmets are a necessity in the UK. The only time I don’t wear one is when in  The Netherlands
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:07 +0000 2020
# Tweet content:
#  RT @pythonbrasil: Ainda não submeteu sua proposta de atividade para a Python Brasil? Então se apresse, as submissões encerram dia 21 de set…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:07 +0000 2020
# Tweet content:
#  6 Ways Artificial Intelligence and Machine Learning Can Improve Your Marketing #Learning #marketing  https://t.co/qeA7c6oXjH
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:10 +0000 2020
# Tweet content:
#  RT @MJalalimanesh: #100DaysOfMLCode
# Sentiment analysis of a food review dataset with bag-of-words model using pegasos classifier. Most pos…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:11 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to construct a complete binary tree from given array
# https://t.co/G4UwAvK4WT
#
# #Cppsecrets #cppsecrets #python3…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:11 +0000 2020
# Tweet content:
#  RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.
# Rotterdam-Amsterdam: 75 km, 45 minuts en tren
# Manresa-Barcelona: 60 km, 1h 30 en tren.
# Ut…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:11 +0000 2020
# Tweet content:
#  RT @rubenkoops: Burgemeester Halsema kondigt aan in gesprek gaat met de verhuurder van de megakerk Hillsong in Amsterdam, omdat dit een bro…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:11 +0000 2020
# Tweet content:
#  C++ program to find largest number in binary search tree which is less than or equal to N
# https://t.co/2ZXXxFfT5J… https://t.co/F9zvTaa5Du
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:12 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to check if a given binary tree is sumtree
# https://t.co/8sT8cI4wSi
#
# #Cppsecrets #cppsecrets #python3 #python #c…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:13 +0000 2020
# Tweet content:
#  @rachsyme The Netherlands and then India, ideally spending a few weeks traveling through Asia after wrapping my internship.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:13 +0000 2020
# Tweet content:
#  RT @JAYEKlNG: I’ve been Amsterdam so many times but nothing will ever top the first time I went
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:14 +0000 2020
# Tweet content:
#  RT @acityinohio: almost all of cryptocurrency governance is an extended Monty Python sketch https://t.co/mv0VAIarcT
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:14 +0000 2020
# Tweet content:
#  RT @Shradha55989917: What are the best artificial Intelligence certifications?
# https://t.co/iEdVwvZze0
#
# #ArtificialIntelligence #MachineLea…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:14 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to find minimum depth of a binary tree
# https://t.co/JuJMge31Ey
#
# #Cppsecrets #cppsecrets #python3 #python #cplus…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:16 +0000 2020
# Tweet content:
#  RT @CoastObsProject: Have you heard of @CMEMS_EU's 🆕 tool? It's called My Ocean 🌊 &amp; is mobile friendly 📱
#
# It's a fast and accurate ocean vi…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:16 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to find level with maximum number of nodes
# https://t.co/dZnoch33p3
#
# #Cppsecrets #cppsecrets #python3 #python #c…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:16 +0000 2020
# Tweet content:
#  RT @mattmayo13: Implementing a Deep Learning Library from Scratch in Python - KDnuggets https://t.co/2SdqeYxydS https://t.co/MiifS0mA9x
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:17 +0000 2020
# Tweet content:
#  Visual Studio Code is an awesome editor! Awesome work @Microsoft !!!
# #Microsoft #technology #nodejs #reactjs #html… https://t.co/BPYicWGcME
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:17 +0000 2020
# Tweet content:
#  RT KirkDBorne: What is Artificial Intelligence? Explained in 101 seconds by
# @GaryZero @Qualcomm [video]:… https://t.co/LNjg1RbWCz
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:17 +0000 2020
# Tweet content:
#  RT @archangeljf12: Artificial intelligence program used against ISIS now used by DNC against Trump &amp; supporters online https://t.co/qZZsSTe…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:18 +0000 2020
# Tweet content:
#  @jy_labouche En voyant ce tweet, j'ai essayé de programmer sur scratch que je n'avais plus utilisé depuis des année… https://t.co/qKxu1HUjZV
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:18 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:18 +0000 2020
# Tweet content:
#  #Python https://t.co/kS9pmPMZz5
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:18 +0000 2020
# Tweet content:
#  RT @johnanthonycode: Visual Studio Code is an awesome editor! Awesome work @Microsoft !!!
# #Microsoft #technology #nodejs #reactjs #html #ja…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:18 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to find averages of levels in binary tree
# https://t.co/6TeEzLTGsx
#
# #Cppsecrets #cppsecrets #python3 #python #cp…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:18 +0000 2020
# Tweet content:
#  noviyanti sagala earned a statement of accomplishment on DataCamp for completing Introduction to Python!… https://t.co/TRLOgpiRWN
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:19 +0000 2020
# Tweet content:
#  Filed under things Republicans will never tell their followers.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:19 +0000 2020
# Tweet content:
#  RT @TheWolfpackIN: IAF's own CoBRA Group will likely lead any initiatives of IAF involving the applications of Artificial Intelligence (AI)…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:20 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to get level of a node in binary tree without using recursion
# https://t.co/mAD1WqIeQ8
#
# #Cppsecrets #cppsecrets…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:22 +0000 2020
# Tweet content:
#  RT @MicrosoftUK: It's National Coding Week here in the UK!
#
# Whether you are a C# student or a Python pro, it's never too late to brush up…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:22 +0000 2020
# Tweet content:
#  RT @GGFN_: Bayern Munich have agreed a 5-year provisional contract with Sergiño Dest, according to Sky Germany. Bayern officials travelled…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:22 +0000 2020
# Tweet content:
#  RT @johnanthonycode: Visual Studio Code is an awesome editor! Awesome work @Microsoft !!!
# #Microsoft #technology #nodejs #reactjs #html #ja…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:23 +0000 2020
# Tweet content:
#  @isagato62 @TheActionNet metoo!
# https://t.co/cGfl69fmdr
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:23 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to find number of subtrees having odd count of even numbers
# https://t.co/9TlTMx3Gsi
#
# #Cppsecrets #cppsecrets #p…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:23 +0000 2020
# Tweet content:
#  RT @hope_ssr: NCB got leads that Prime accused Rhea used to order drugs from outside India, Especially from Netherlands #ArrestSSRKillersNow
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:23 +0000 2020
# Tweet content:
#  Eigenaar Mall of the Netherlands stelt financieel noodplan op &gt; https://t.co/4G1az3rdx2 #retail
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:24 +0000 2020
# Tweet content:
#  RT @ianmSC: Holy cow. This is unbelievable.
#
# The science and data is overwhelming tonight.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:24 +0000 2020
# Tweet content:
#  RT @UberFacts: In 2013, 19 prisons in the Netherlands closed because the country didn't have enough criminals to fill them.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:25 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to find the maximum sum leaf to root path in a binary tree
# https://t.co/ipIDVMbJUh
#
# #Cppsecrets #cppsecrets #py…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:26 +0000 2020
# Tweet content:
#  RT @TheWolfpackIN: IAF's own CoBRA Group will likely lead any initiatives of IAF involving the applications of Artificial Intelligence (AI)…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:27 +0000 2020
# Tweet content:
#  RT @lifebiomedguru: FDA has never conducted a dose escalation study of aluminum in mice.  #IPAK has invited and has received a proposal for…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:28 +0000 2020
# Tweet content:
#  RT @cppsecrets: C++ program to find root to leaf path with maximum distinct nodes
# https://t.co/o6goVnPTkk
#
# #Cppsecrets #cppsecrets #python3…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:28 +0000 2020
# Tweet content:
#  ここ2週間くらい24時間稼働で動かしてたPythonコード、セミコロンの書き忘れで１日止まったの泣きたい。。。
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:28 +0000 2020
# Tweet content:
#  RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:31 +0000 2020
# Tweet content:
#  What you see or think should not be the determinant. It should be science and data!
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:32 +0000 2020
# Tweet content:
#  A1 13159 Rit 82128 Amsterdam Oosterpark 1091AC OLVGO B3 lounge https://t.co/tzk2TJQX6j #p2000
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:32 +0000 2020
# Tweet content:
#  RT @KirkDBorne: Object Detection with 10 lines of code: https://t.co/q4LPOzCbwI
# ——————
# #BigData #DataScience #AI #MachineLearning #DeepLear…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:32 +0000 2020
# Tweet content:
#  15:29:31 A1 13159 Rit 82128 Amsterdam Oosterpark 1091AC OLVGO B3 lounge
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:33 +0000 2020
# Tweet content:
#  RT @TaxJusticeNet: New polling published by @MiC_Global shows overwhelming public support in the US, France, Germany, Italy, Poland, the Ne…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:33 +0000 2020
# Tweet content:
#  RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:34 +0000 2020
# Tweet content:
#  RT @hope_ssr: NCB got leads that Prime accused Rhea used to order drugs from outside India, Especially from Netherlands #ArrestSSRKillersNow
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29:36 +0000 2020
# Tweet content:
#  Balende horeca Texel over code rood: "Gestraft voor besmettingen in Amsterdam" https://t.co/JMjeCmla3o
#
# Expecting value: line 2 column 1 (char 1)
# Imported tweet created at: Thu Sep 17 13:29
# en
# en
# en
# en
# en
# en
# nl
# en
# en
# de
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# nl
# en
# en
# pt
# en
# nl
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# es
# en
# en
# en
# en
# en
# fr
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# es
# nl
# ja
# nl
# en
# en
# en
# en
# en
# en
# en
# nl
# en
# en
# nl
# en
# nl
# en
# en
# es
# nl
# en
# en
# en
# en
# en
# es
# en
# en
# en
# en
# en
# en
# en
# en
# en
# et
# ja
# en
# de
# en
# nl
# nl
# en
# en
# und
# ja
# en
# en
# en
# en
# en
# en
# en
# nl
# fr
# en
# en
# pt
# en
# en
# en
# en
# en
# en
# en
# es
# en
# en
# en
# en
# ja
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# und
# en
# en
# und
# en
# en
# en
# en
# en
# es
# en
# en
# en
# en
# en
# en
# en
# en
# en
# es
# en
# fr
# es
# en
# en
# en
# en
# en
# en
# en
# en
# en
# zh
# en
# en
# pt
# en
# en
# fr
# pt
# en
# en
# en
# und
# nl
# en
# en
# und
# en
# en
# nl
# und
# en
# en
# en
# fr
# en
# en
# pl
# fr
# en
# en
# en
# en
# en
# en
# en
# fr
# en
# en
# en
# en
# en
# en
# en
# pt
# ja
# en
# en
# en
# en
# in
# en
# en
# en
# en
# en
# en
# en
# en
# pt
# en
# en
# pt
# en
# en
# en
# en
# ar
# en
# en
# und
# en
# nl
# en
# en
# ja
# nl
# en
# en
# tl
# en
# en
# en
# en
# en
# en
# es
# en
# nl
# en
# en
# pt
# en
# en
# en
# en
# tl
# en
# en
# fr
# en
# en
# en
# en
# en
# en
# en
# en
# pt
# en
# en
# en
# en
# en
# en
# und
# en
# nl
# es
# en
# en
# en
# en
# en
# nl
# en
# en
# en
# pt
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# nl
# ja
# ja
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# pt
# fr
# nl
# en
# en
# en
# en
# en
# en
# pt
# en
# en
# en
# nl
# nl
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# en
# fr
# en
# und
# en
# en
# en
# en
# en
# en
# en
# en
# en
# es
# en
# en
# nl
# en
# en
# en
# en
# en
# en
# ja
# en
# en
# nl
# en
# nl
# en
# en
# en
# nl
# en
# en

# %%
list(map(lambda tweet: tweet['text'], tweets_data))
# Out:
# ['#WO2 (20-05-1940 (Opname)) Het koffiehuis, Amsterdam. https://t.co/DJwmf1lAeU NIOD: https://t.co/yq1Gm4VfVt',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  "RT @TruthSeeker____: Footage Of Biden Touching Girls On C-Span Flagged As Child Sexual Exploitation By By Twitter's Artificial Intelligence…",
#  '@SaleemKhanSafi \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'Greetings from the Left Coast!\n\n20 years ago in Amsterdam, I discovered that you could order a Red Bull and Vodka c… https://t.co/nTMBSpvNFz',
#  'RT @VivaanChaudhar6: Gain advanced skills in analytics and transform your career. We at DataTrained provides hands on online Data Science t…',
#  'RT @RonLiOfficial: Code should talk\n.\n.\nFollow us on Instagram: https://t.co/dmdTTYHdCz\n.\n.\n#100daysofcode #codenewbie #developer #programm…',
#  'RT @_nasch_: Aprobado en tiempo récord y mi regalo para ustedes, gratis por tan sólo 3 días mi curso: Python sin fronteras. https://t.co/8w…',
#  'RT @ErrikB: Gisteren sprak wethouder @mvdoorninck de eerste Van der Vlislezing uit. Terugkijken naar de jaren 80 en vooruitblikken op hoe A…',
#  'Is there not anyone in the Chicago media willing to do their job? @GovPritzker is destroying businesses, preventing… https://t.co/NbzmDKjps0',
#  'RT @sofiesyarief: HAHAHAHA https://t.co/q7NY8cyWRA',
#  "@WebReflection Already done by Haxe. It's ECMAScript-based language + optionally ADT, pattern matching, decorators… https://t.co/chaDv8JyDA",
#  'RT @llanga: #Python 3.9.0 is almost ready! The final preview release, RC2, is now available. Get it here:\n\nhttps://t.co/Lyo50dqKdi\n\nAs ever…',
#  'RT @course_net: #MachineLearning  \nTesting and Monitoring Machine Learning Model Deployments | Course\n\n=&gt; https://t.co/ES3oeNwHFa\n\n#DataSci…',
#  "@JoostSchreurs @EliannevT Ja, dan had Jan Roos waarschijnlijk bij de foto de tekst 'de burgemeester van Amsterdam' geplaatst...",
#  'B1 (medium care) 13152 Rit 82114 Amsterdam Oosterpark 1091AC OLVGO C3 ccu https://t.co/DYJxwk7eak #p2000',
#  'RT @HMDatabase: #STMF updated&amp;revised ✅\n➡️New country Northern Ireland\n➡️Croatian data avail up to 2020\n‼️Picks of excess #mortality in sum…',
#  'They need to tell us the % false positive rate, otherwise the data is meaningless. The fact they don’t means either… https://t.co/b6FIrzZw0Y',
#  "RT @MaxGraey: @WebReflection Already done by Haxe. It's ECMAScript-based language + optionally ADT, pattern matching, decorators and reflec…",
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'pythonのこと数ヶ月前のわたしは大好きだったけど、今のわたしは嫌いだぞ',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/RoYMKeKGE9',
#  'RT @pronoiai: One thing Rhea will be well educated on and that is where certain countries are in the world - geography lessons.\n#ArrestSSRK…',
#  '14:33:24 B1 (medium care) 13152 Rit 82114 Amsterdam Oosterpark 1091AC OLVGO C3 ccu',
#  'RT @pythonbot_: Algorithms to Live By: The Computer Science of Human Decisions https://t.co/iA0GXqxDLV  #python #ad',
#  'RT @course_net: #MachineLearning  \nTesting and Monitoring Machine Learning Model Deployments | Course\n\n=&gt; https://t.co/ES3oeNwHFa\n\n#DataSci…',
#  '@hmaon @KevinCu13907262 @HomeGirl_Shelly @ConservBlue2020 You cannot pull a website from with old data from a googl… https://t.co/W4DoUZui0F',
#  '(#3FBC77) as flight #ABLE13 at 698 ft heading north bound over Utrecht (The Netherlands). At: https://t.co/znD8UqeqKW',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  '@HamidMirPAK \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  '会社のPCにCUDAとcuDNN入れて、pythonでGPUコンピューティングしたろ！と思って空き時間にちゃちゃっと入れたは良いものの、肝心のcupyが動かず死亡。\n\ntensorflowはgpu認識しているみたいだし、この辺は気… https://t.co/F38F3qu0ls',
#  'Overval op belwinkel Amsterdam-Oost https://t.co/33jyVJZSTu',
#  'C++ std::is_sorted with std::list\nhttps://t.co/NMjli9gAab\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/ca3rWDesQU',
#  'https://t.co/Gw3rcAACn1‘Bijnaiemand kan uitleggen wat data analytics toevoegt’Machine learning, artificial intellig… https://t.co/CmBeoctDon',
#  'RT @PinakiLaskar: Life\n\n#ArtificialIntelligence #MachineLearning #BigData #DataScience #AI #IoT #Python #RStats #Java #JavaScript #ReactJS…',
#  'RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…',
#  'RT @asffofficial: ⚡️« La hija de un ladrón » (A thief’s daughter), a film by @_belenfunes_ , will officially premiere at the #SpanishFilmFe…',
#  'RT @falsel_net: Amsterdam   ❌❌❌\nIncidence #SARSCoV2 per 100k last 7 d   170,4  \n\nRotterdam\nIncidence #SARSCoV2 per 100k last 7 d   128,0…',
#  "@Marco_Langbroek What altitude for the stage is assumed here? I'm currently at 11°E 53°N, about twice as far from t… https://t.co/fEz9bxj5kK",
#  '@mackflinx Amsterdam !',
#  'RT @cppsecrets: C++ std::is_sorted with std::list\nhttps://t.co/NMjli9gAab\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming…',
#  'RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…',
#  "@ParisDaguerre Nope he'll go on to make millions in Monty Python's Flying Circus",
#  'RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…',
#  'RT @RightToLifeUK: The experience of the Netherlands should be a cautionary tale for countries debating assisted dying, @TheoBoer argues fo…',
#  'RT @MarioMonforte: Intel Core i9 is the best processor for creators, you can make a movie or an artwork. Brign your dreams to life, or crea…',
#  '@shazbkhanzdaGEO \nhttps://t.co/E4GiDnzg96 - admin',
#  '@Supremacy3rd @Roblox_RTC -new uploads by a specific creator. You can copy URLs and paste them in the dialog box. I… https://t.co/XUDsZxkjj4',
#  "RT @Analytics_699: #AV get it's first tunnel loop ready in #LasVegas ▶️\n\n#Analytics #MachineLearning #AI #Python #javascript #TensorFlow\n#I…",
#  'RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…',
#  'RT @MdOmarzai: I will start learning #webdevelopment  and #python on 18/09/2020 let’s go for sth big:).      I will share my one week job.…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/e2iVLyoj9m',
#  'RT @ryanstruyk: Confidence in President Trump in poll of 13 countries via \n@pewresearch:\n\n25% Japan\n23% Australia\n20% Canada\n19% United Kin…',
#  'RT @earthcurated: Amsterdam, Netherlands https://t.co/iU37txRL1d',
#  'RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.\nRotterdam-Amsterdam: 75 km, 45 minuts en tren\nManresa-Barcelona: 60 km, 1h 30 en tren.\nUt…',
#  'If you’re coming from other languages, e.g. #Python python, watch out when concatenating two arrays in #javascript.… https://t.co/KlbUr7sHDo',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  "The way there's actually a two-headed calf in a zoo run by a cult-ish group in Dumaguete... They had a python all t… https://t.co/puhoOgAgIb",
#  'RT @steeph: Shit',
#  'RT @JKDubai1: 🇵🇰🇦🇹🇦🇹🇵🇰\nPAK - AUSTRIA\n\nToday PM @ImranKhanPTI inaugurated Pak-Austria Fachhochschule Institute of Applied Sciences &amp; Technol…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @_nasch_: Aprobado en tiempo récord y mi regalo para ustedes, gratis por tan sólo 3 días mi curso: Python sin fronteras. https://t.co/8w…',
#  '【CV上坂すみれ】AI・機械学習入門第二弾！音声データから、声優を識別するAIを創る！\n 5秒で学習を始められる、Python×動画×オンライン実行環境によるAI入門者、機械学習入門者向けコンテンツです https://t.co/sJJh4kTPZN #声優識別AI',
#  'Fisher 31\n€ 36,900 \nCountry: Netherlands \nYear built: 1980 \nLOA (m): 9.5 \nHull material: GRP \nFuel: Diesel… https://t.co/hUOi1wHVxF',
#  'RT @course_net: #MachineLearning  \nTesting and Monitoring Machine Learning Model Deployments | Course\n\n=&gt; https://t.co/ES3oeNwHFa\n\n#DataSci…',
#  '@tancredipalmeri Tu sei stato ad Amsterdam sembra.... Ah no, per te é la normalità la disinformazione',
#  'RT @hype4com: If you’re coming from other languages, e.g. #Python python, watch out when concatenating two arrays in #javascript. The resul…',
#  '@ScuderiaFerrari https://t.co/H4IfSv6kl0    \nOn Oct. 29, 2014, The Imperial Banquet was held at the Imperial Palace… https://t.co/UMEKc1qIgw',
#  'RT @FootballOranje_: What are your thoughts on the likely appointment of Frank de Boer as Netherlands boss?',
#  'RT @infomubashir: After witnessing #panther #bigcats &amp; #Deer on #Hyderabad city roads during #lockdown now city witnessed   #Python &amp; #Croc…',
#  '@Matiullahjan919 \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @OneKindesign: Modern villa in Amsterdam offers fabulous indoor-outdoor connectivity https://t.co/sjJcXbvPts https://t.co/amMnXE0BFH',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @LindaBowmanL: What’s it going to take to change peoples minds ?  Logic, science, medicine it’s all there!!! Please make the right choic…',
#  'RT @Dr_MariamMatar: .\nصباحكم وطن يتباهى بأبناءه المخلصين في كل الميادين🇦🇪 \n.\nالله يوفق لخير البلاد والعباد🌹 ألف مبروك د.سعيد الظاهري',
#  'Phillip II joined Charles and outlawed Protestantism as well as sent the Inquisition to the Netherlands. The Inquis… https://t.co/0T00vI0Rwa',
#  '@voorschot I’ve been to Noord Holland twice in the last week. The ticket even has been issued by Amsterdam Centraal… https://t.co/79YNv7ECHB',
#  'RKI meldet neue Risikogebiete in Europa, Reisewarnungen folgen Wien und Amsterdam betroffen https://t.co/C5Hucszo0L https://t.co/Gy8FDwWUXd',
#  '@realDonaldTrump Math, science, data analytics, human compassion... all concepts too hard for you and your Admin. SMDH.',
#  'RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…',
#  'Data Science and Engineering E-Degree (2020) Eduonix Coupons - https://t.co/V0HnbRrtOP\n-\n #datascience #science',
#  'C++ std::is_sorted with std::vector\nhttps://t.co/6XEBjJe6CU\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/LbhN974yXO',
#  'RT @palazzo214: @RexChapman Yes, America is divided...on masks of all things. Which one are you?\n\nTeam NO MASK: me me me American (ie. Trum…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/lG4DCSCoaf',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @cppsecrets: C++ std::is_sorted with std::vector\nhttps://t.co/6XEBjJe6CU\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programmi…',
#  'RT @antgrasso: Getting the most out of Data Science is not impossible but it does require some knowledge.\n\n@OracleItalia has organized a fr…',
#  'RT @VincenzoSelXXX: Subscribe for more... 💦 drakes Amsterdam gloryhole!\n\nWhole 73 min video at:\nhttps://t.co/Dz6WJxxNj5  \nhttps://t.co/nbyu…',
#  'RT @cppsecrets: C++ std::is_sorted with std::vector\nhttps://t.co/6XEBjJe6CU\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programmi…',
#  "RT @bajcmartinez: @DevShehu @_Thorby That's correct. They are not a very popular feature in JS compared to other languages like Python, but…",
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  "Artificial intelligence is changing SEO. Here's what you'll need to do to optimize for machine learning and termina… https://t.co/xjHPvGy7V1",
#  'RT @RepsForBiden: The world is laughing at you @realDonaldTrump \nUnfortunately, we all pay the price.',
#  'First #ArtificialIntelligence gadgets for the home.\n@GeorgeWillems1 @BViseeon @SiddharthKS  @RLDI_Lamy @baski_LA… https://t.co/py8uia1cGg',
#  'Video...Greece...Island...Lesbos...Police...Clear...Street...Migrant...overcrowd...Moria...facility...destroy...fir… https://t.co/CWjRbwQWM8',
#  'RT @Entrepreneurix: Van #D66 wisten we het al, maar ook de #VVD-ers blijken gewoon #EU systeemclowns te zijn geworden.\n\nWaarom is de EU zo…',
#  'RT @BBWfan9: The heat is on in the netherlands today! https://t.co/PoY1WbmCfY',
#  "RT @watherkiller: Il y a un 1 ans jour pour jour je vivais l un de mes meilleurs jour en tant que supporter du losc a Amsterdam et aujourd'…",
#  '学習498日目\u30001.0時間\n累計：689.4時間\n技術：Python\nプログラミング演習 Python2019 15Pまで読了\n #TechCommit',
#  'なんで今頃Pythonの勉強を始めたかってそりゃあなたAtCoderに参戦するためですよ',
#  'RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.\nRotterdam-Amsterdam: 75 km, 45 minuts en tren\nManresa-Barcelona: 60 km, 1h 30 en tren.\nUt…',
#  'RT @DevelopmentPk: PM Imran Khan inaugurated another flagship project of #KP Government, Pak-Austria Fachhochschule University, #Haripur. U…',
#  'Laura. Thank you for telling the truth and updated.',
#  'RT @glenannefilm: A huge rise in DVD requests internationally after last night’s screening. This batch posting to Australia, US, Netherland…',
#  '@peaceforchange \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @Entrepreneurix: https://t.co/iCp84jD95x\n\nPicture of #StefBlok and Joseph Borrell makes you understand why the Dutch Minister of Foreign…',
#  'RT @MIGOPChair: And this surprises ...anyone?Whitmer continues to HIDE 🤐 the "science and data" and ANY information concerning her deadly n…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/yft70IWfi7',
#  'RT @mygovindia: Are you an AI enthusiast and you think your innovative AI solution has the power to solve societal challenges? Then we have…',
#  'RT @s_kampakis: What Do Experts Say About the Future of #MachineLearning (and Python)? #AI #DataScience via @STXNext https://t.co/QuroAiA02Q',
#  'RT @Datagraver: Update status #covid19 for the Netherlands\nhttps://t.co/2pd5WlSoJr\n1753 cases, 6 fatalities, 14 hospitalizations reported t…',
#  'RT @KirkDBorne: What is Artificial Intelligence? Explained in 101 seconds by \n@GaryZero @Qualcomm [video]: https://t.co/YU5aeFTsuF\n—————\n#A…',
#  "RT @kylamb8: This isn't the killer of younger or healthier people that other viruses have been. But we knew that since median age dying is…",
#  "@dracaryskz i wanted it but i just bought the standard bc it doesn't ship to the netherlands :(",
#  'United States Air Force Lockheed C-130H Hercules (95-6711, #ADFDD5) at 800 ft heading north bound over Utrecht (The… https://t.co/TM0Uuc3CZj',
#  'RT @Locat1ons: Haarlem, Netherlands 🇳🇱\nvia: amsterdamcanals https://t.co/Xkdt6AsqQN',
#  'RT @DataScience_b: Role-playing dimensions in Power BI\nhttps://t.co/Z22KVlyvD5\n #data #science #datascience',
#  'RT @DataScience_b: Pandas has superpowers in reading Excel files\nhttps://t.co/0IakiU8lzs\n #data #science #datascience',
#  'RT @s_kampakis: What Do Experts Say About the Future of #MachineLearning (and Python)? #AI #DataScience via @STXNext https://t.co/QuroAiA02Q',
#  'RT @ds_vault: Data Science and Engineering E-Degree (2020) Eduonix Coupons - https://t.co/V0HnbRrtOP\n-\n #datascience #science',
#  'RT @_Nitin__Rawat_: What is 3090 ? 😂\n#Coding #5G #applewatchseries6 #code #programming #AI #javascript30 #programfolback \n#100DaysOfCode #P…',
#  'RT @hype4com: If you’re coming from other languages, e.g. #Python python, watch out when concatenating two arrays in #javascript. The resul…',
#  'RT @DataScience_b: Modeling Topic Trends in FOMC Meetings\nhttps://t.co/KbF60YPvHp\n #data #science #datascience',
#  'RT @course_net: #MachineLearning  \nTesting and Monitoring Machine Learning Model Deployments | Course\n\n=&gt; https://t.co/ES3oeNwHFa\n\n#DataSci…',
#  'RT @DataScience_b: How to Manage a Junior Data Scientist\nhttps://t.co/P3DkHT91Zq\n #data #science #datascience',
#  'RT @RonLiOfficial: Code should talk\n.\n.\nFollow us on Instagram: https://t.co/dmdTTYHdCz\n.\n.\n#100daysofcode #codenewbie #developer #programm…',
#  'RT @Courseverse: Master Complete Statistics For Computer Science - I ($94.99 to Free) #100DaysOfCode #DataScience #MachineLearning #IoT #Ja…',
#  'RT @works_delight: In what order do you have to learn web development?\n\nHtml (10 days).....Css (10 days)\nJquery(20 days).....Bootstrap( 20…',
#  'RT @antgrasso: Getting the most out of Data Science is not impossible but it does require some knowledge.\n\n@OracleItalia has organized a fr…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'PropertyEU Netherlands Roundtable: distress looming as capital continues to chase core product… https://t.co/bHYYcr8GQ9',
#  'Amsterdam, The Netherlands\n  It has gradually become the most multicultural and liberal city in the world. Amsterda… https://t.co/TRawkVVHiQ',
#  'Michael Galarnyk, a skilled data science instructor, joins us to answer your questions about data science education… https://t.co/oz7vB2tSpC',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @acityinohio: almost all of cryptocurrency governance is an extended Monty Python sketch',
#  'The military is working on game-changing technologies, such as artificial intelligence and 5G, and looks to move th… https://t.co/b77DVW10Jm',
#  'RT @PythonInsider: Python 3.9.0rc2 is now available for testing https://t.co/wyLUn3Zyum',
#  'C++ std::fill with std::array\nhttps://t.co/GjWIizORCd\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/0fXjFUAO8U',
#  '@EliannevT Nee nu insinueer jij dat ik insinueer dat Jan kennis heeft. Dat terwijl iedereen wel kan nagaan dat Hals… https://t.co/lwX6AXbMIf',
#  'RT @Ben_garrod: It doesn’t take much to make us academics happy ... you know what to do :)',
#  'RT @AbdulBa54505576: #Android RecyclerView with #Kotlin https://t.co/eB29YC26yY\n\n#100DaysOfCode #JavaScript #CodeNewbie #Java #developer #A…',
#  'Imagine influencing so many with your science (and the charisma that accompanied it) ⭐️',
#  '@RMConservative If a university closed campus &amp; sent kids home with no plan back in March based on faulty science/d… https://t.co/5rLyCIXsP8',
#  '@Benazir_Shah \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @KimDotcom: The US govt operates massive data centers with the capacity to store all human communications for decades. The data is highl…',
#  'RT @cppsecrets: C++ std::fill with std::array\nhttps://t.co/GjWIizORCd\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #co…',
#  'RT @rubenkoops: Burgemeester Halsema kondigt aan in gesprek gaat met de verhuurder van de megakerk Hillsong in Amsterdam, omdat dit een bro…',
#  'RT @glenannefilm: A huge rise in DVD requests internationally after last night’s screening. This batch posting to Australia, US, Netherland…',
#  '（実は…Pythonを「ファイトン」と読んでました😅\n先日書店で本を見ているときに、ふりがなが振ってある本がありまして、「パイソン」と書いてありましてね…えぇ、一人で心の中で「恥ずかしー💦」ってなってました😅）',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  '@whitehawk1186 @GovNedLamont https://t.co/x3lCCMSY4y\n\nWow you clearly don’t have basic understanding of how science… https://t.co/Ax17TxdswR',
#  'RT @Datagraver: Update status #covid19 for the Netherlands\nhttps://t.co/2pd5WlSoJr\n1753 cases, 6 fatalities, 14 hospitalizations reported t…',
#  'RT @Analyticsindiam: #Tutorial\nHoloviews is an #opensource #python library that makes #datavisualization easier.\nRead more here - https://t…',
#  'RT @JustinWolfers: Change in the unemployment rate since January:\nU.S.A. +4.8%\nCanada +4.7%\nAustralia +2.2%\nSpain +2.0%\nSweden +2.0%\nMexico…',
#  'RT @gvanrossum: [Repeat so more people are aware of this]\nPython 4 FAQ.\n1. The version after 3.9 is 3.10; in fact it already exists (in git…',
#  'RT @BTS_twt: Amsterdam 1/2 😲 with쩨이홉 https://t.co/QEzqkiPYUr',
#  'RT @JustinWolfers: Change in the unemployment rate since January:\nU.S.A. +4.8%\nCanada +4.7%\nAustralia +2.2%\nSpain +2.0%\nSweden +2.0%\nMexico…',
#  'RT @btsdutchstats: Spotify Netherlands 🇳🇱 \n\n#29 (+3) *new peak* ‘Dynamite’ 95,160 🔼\n\nTotal: 1,904,011\n\n@BTS_twt https://t.co/Ab4FZvmbpj',
#  'RT @gp_pulipaka: The Essential Amazon #AWS Books for Cloud Professionals. #BigData #Analytics #DataScience #IoT #IIoT #Python #RStats #Tens…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/PqrEEgCffV',
#  '@banaanpankoek @turtlejoestin Jaa preciess self made brands! Ik ken en paar van jonge ondernemers in amsterdam en z… https://t.co/wRvLaqokGo',
#  "@willzknight @bicycal_life @AnnChivers2 @Chris_Boardman It's not when it adds one extra thing to what you have to c… https://t.co/xiChLbhgjU",
#  'RT @ianmSC: Holy cow. This is unbelievable. \n\nThe science and data is overwhelming tonight. https://t.co/BXucVQmk2b',
#  'RT @hope_ssr: NCB got leads that Prime accused Rhea used to order drugs from outside India, Especially from Netherlands #ArrestSSRKillersNow',
#  '&gt;&gt;&gt;---&gt;@GovInslee #MaggotJay',
#  'It\'s obvious - "1,2,34,5,6"',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @ShellenbergerMD: For decades everybody thought nuclear energy was dead in the Netherlands\n\nBut now, the government is seriously explori…',
#  '#AUS #entrepreneur #techcomm Have you heard of #ArtificialIntelligence #AI for app &amp; websites? We can show you the… https://t.co/qKbA5OJYrX',
#  "RT @malkusm: Now a whole lot of people know what I've known about the situation in Nashville for weeks.\n\nNot only is our COVID policy not d…",
#  '@AmberRShamsi \nhttps://t.co/E4GiDnzg96 - admin',
#  'Nice.',
#  'RT @olgatuleninova: "Peasant Woman Binding Sheaves".(1889)\nBy Vincent van Gogh.Dutch post-impressionist\nVan Gogh Museum. Amsterdam https://…',
#  'RT @s_adamiak: It\'s obvious - "1,2,34,5,6" https://t.co/UUSKQIXHOJ',
#  "RT @MicrosoftUK: It's National Coding Week here in the UK! \n\nWhether you are a C# student or a Python pro, it's never too late to brush up…",
#  'RT @mygovindia: Are you an AI enthusiast and you think your innovative AI solution has the power to solve societal challenges? Then we have…',
#  "RT @NL_Times: Netherlands' Covid testing system not ready for second wave, Inspectorate says https://t.co/L5bQa7HjXP",
#  'RT @BTS_twt: Amsterdam 2/2 📸🤨 https://t.co/63iq5qvSXl',
#  '@BitcoinBiology @_jonasschnelli_ @BitcoinAustrian Science is also about observing, collecting data, and interpretin… https://t.co/L7N02ZaON7',
#  'RT @Datagraver: Update status #covid19 for the Netherlands\nhttps://t.co/2pd5WlSoJr\n1753 cases, 6 fatalities, 14 hospitalizations reported t…',
#  'A Place of Refuge: Rome and Amsterdam | Al Jazeera\xa0World https://t.co/P0KKd3YCFt',
#  '@meckimac @elonmusk @ID_AA_Carmack @lexfridman Just Heard, only available in switzerland, Norway and netherlands. A… https://t.co/FXPCENMKnm',
#  'RT @course_net: #MachineLearning  \nTesting and Monitoring Machine Learning Model Deployments | Course\n\n=&gt; https://t.co/ES3oeNwHFa\n\n#DataSci…',
#  'RT @ZRAFC: Bayern has already agreed a five-year contract with Barca target Sergino Dest and negotiations with Ajax Amsterdam have intensif…',
#  'RT @contempediacom: #development \nMaster Laravel with GraphQL, Vue.js and Tailwind | Course =&gt; https://t.co/SPbpdW8GrK\n\n#100DaysOfCode #ude…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/0gVUCm0MBZ',
#  'RT @gp_pulipaka: The Essential Amazon #AWS Books for Cloud Professionals. #BigData #Analytics #DataScience #IoT #IIoT #Python #RStats #Tens…',
#  'RT @RitupaGhosh: First #ArtificialIntelligence gadgets for the home.\n@GeorgeWillems1 @BViseeon @SiddharthKS  @RLDI_Lamy @baski_LA @Nicochan…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @contempediacom: #development \nMaster Laravel with GraphQL, Vue.js and Tailwind | Course =&gt; https://t.co/SPbpdW8GrK\n\n#100DaysOfCode #ude…',
#  'RT @toyosirise: Recruiters mostly evaluate candidates’ potential by their work. Beyond saying what you do, it is important to show it.\n\nHer…',
#  'RT @RitupaGhosh: First #ArtificialIntelligence gadgets for the home.\n@GeorgeWillems1 @BViseeon @SiddharthKS  @RLDI_Lamy @baski_LA @Nicochan…',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'https://t.co/LX5l1Dtgsw\nhttps://t.co/Kf0t1TQmkN\nhttps://t.co/TpUyEujAst\nhttps://t.co/sKa6TFYDgq)… https://t.co/VAK8nwsAFW',
#  'Threats are difficult to investigate but they deserve special attention. Not only they have a strong impact on thos… https://t.co/dvUUKVcOmY',
#  'Nieuwe #vacature: Projectleider Steigerbouw en Isolatie Locatie: Amsterdam .. https://t.co/ZL1wbXWQKG #vacature #banen',
#  'RT @couponed_code: Data Science 2020: Data Science &amp; Machine Learning in Python \n\n🗼https://t.co/Pnplyz91FY🗼\n\n#DeepLearning #Analytics #Data…',
#  'C++ std::fill with std::forward_list\nhttps://t.co/i9YxsuszIs\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/HoLNlG0lMO',
#  "RT @allofbach: Richard Egarr plays this Concerto in D major, BWV 972, under the watchfull eye of Rembrandt's 'The Night Watch'. Performed o…",
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @Kenosha_News: During World War II, Allied paratroopers launched Operation Market Garden, landing behind German lines in the Netherlands…',
#  'Whe love you to Mr President \nLove from the Netherlands for @realDonaldTrump ❤🙏🇺🇸',
#  'RT @ryanstruyk: Confidence in President Trump in poll of 13 countries via \n@pewresearch:\n\n25% Japan\n23% Australia\n20% Canada\n19% United Kin…',
#  'RT @fca_digital: Smart City Strategy and Artificial Intelligence as the ‘New Electricity’  #smartcity #ArtificialIntelligence #InternetOfTh…',
#  'RT @doctormcdougall: It’s always a good sign that you are in the correct relationship when your wife can pick the exact scene from a Monty…',
#  'RT @HOBlTEAR: WHAT KEKE PALMER IS IN AMSTERDAM https://t.co/unyJdWCPnk',
#  'RT @RepsForBiden: The world is laughing at you @realDonaldTrump \nUnfortunately, we all pay the price.',
#  'RT @cppsecrets: C++ std::fill with std::forward_list\nhttps://t.co/i9YxsuszIs\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programm…',
#  '@HassanNisar \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @laiabonetrull: Amb Amsterdam, París i Brussel·les, reclamem a @vestager capacitat per regular les plataformes digitals.\n\nPerquè la tran…',
#  '😍',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/lWIa4GWMWZ',
#  'RT @cppsecrets: C++ std::fill with std::forward_list\nhttps://t.co/i9YxsuszIs\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programm…',
#  'RT @A_Guerzoni: #AI is the future, but could a disconnect between business leaders and policy-makers, when it comes to regulating it, get i…',
#  'RT @ryanstruyk: Confidence in President Trump in poll of 13 countries via \n@pewresearch:\n\n25% Japan\n23% Australia\n20% Canada\n19% United Kin…',
#  'How artificial intelligence is revamping the call center ?\nEnquiry Now :https://t.co/w98cAeFYKM… https://t.co/LgdSF99MNk',
#  '@realDonaldTrump',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @FossasJosep: Vic-Barcelona: 60 km, 1h 30 en tren.\nRotterdam-Amsterdam: 75 km, 45 minuts en tren',
#  'RT @JuvenileCrime: 🌍🌏🌎 is Heating Up 🔥🔥🔥 https://t.co/tw1SCXZSbm',
#  '@StormMasters @NL_Rugby_League In Leiden in the Netherlands',
#  '#TrumpIsANationalSecurityThreat',
#  'Frank de Boer v Tata Martino NEXT MONTH!!! 🚨🚨🚨',
#  '@nadeemmalik \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  '@FrancescoCiull4 👋: Khristian\n🌐: London, UK\n💼: Digi-Ed Director\n👨\u200d💻: HTML, CSS, JS, Python\n💙: Football, wearable tech, wine',
#  'RT @EduMinOfIndia: .@Microsoft in association with @nasscom will offer AI, #MachineLearning &amp; data science expertise to students through ea…',
#  'RT @RonLiOfficial: Code should talk\n.\n.\nFollow us on Instagram: https://t.co/dmdTTYHdCz\n.\n.\n#100daysofcode #codenewbie #developer #programm…',
#  'RT @FrancescoCiull4: 👋Hi, How are you?\n\nIntroduce yourself to other devs!!!\n\n👋: Francesco\n🌐: Italy, Rome\n💼: ESA, Copernicus Project\n👨\u200d💻: JS…',
#  '@removethecaps @AmsterdamNL @Iamsterdam @NLinAustralia @MinPres @ScottMorrisonMP That’s the most Amsterdam view ever!',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/kb5ja4Jfl3',
#  "RT @UberFacts: In 2013, 19 prisons in the Netherlands closed because the country didn't have enough criminals to fill them.",
#  'RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.',
#  'C++ std::fill with std::list\nhttps://t.co/vPeUrhO6j1\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/7skmBe7DwT',
#  'RT @hope_ssr: NCB got leads that Prime accused Rhea used to order drugs from outside India, Especially from Netherlands #ArrestSSRKillersNow',
#  'Day 115 of #NLP365: NLP Papers Summary\u200a-\u200aSCIBERT: A Pretrained Language Model...\nhttps://t.co/uiQSgrKetW\n #data #science #datascience',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @hermanlintvelt: Using #java again on a backend service, after spending time in the python world, and it just feels so solid and safe, a…',
#  'RT @cppsecrets: C++ std::fill with std::list\nhttps://t.co/vPeUrhO6j1\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #cod…',
#  'Finnish Architectural Landscape: A Statistical Cross Section\nhttps://t.co/e1KfKuFqIx\n #data #science #datascience',
#  'RT @sypwynia: Raadsel. De corona-haarden worden vooral gerelateerd aan studenten. Maar de grootste brandhaard is Amsterdam en de grootste c…',
#  'Overlooking Crime in New York City amid the Pandemic and Protests\nhttps://t.co/8X6HktpNkr\n #data #science #datascience',
#  'Tussen Amsterdam Muiderpoort en Amsterdam Amstel is er vertraging en rijden er minder treinen door een defecte trei… https://t.co/Y13Weq7lWh',
#  'How Artificial Intelligence Is Helping Companies Identify &amp; Nail New Product Opportunities https://t.co/6BcpP5U5Go… https://t.co/6MDFIj2oS7',
#  'How Artificial Intelligence Is Helping Companies Identify &amp; Nail New Product Opportunities https://t.co/35eTc1cXow https://t.co/PR5k2NUj2H',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  "RT @UberFacts: In 2013, 19 prisons in the Netherlands closed because the country didn't have enough criminals to fill them.",
#  'Meeting screen, morale and luck sprites, sprites are not correctly centered horizontally with respect to ea…… https://t.co/VXNyDQdl4c',
#  'RT @hope_ssr: NCB got leads that Prime accused Rhea used to order drugs from outside India, Especially from Netherlands #ArrestSSRKillersNow',
#  'Dismissed hero can be bought in tavern with his full army https://t.co/zzmKxWq5K0 #github #C++ #C #Python… https://t.co/uzAiZC68dc',
#  'RT @JuvenileCrime: 🌍🌏🌎 is Heating Up 🔥🔥🔥 https://t.co/tw1SCXZSbm',
#  'RT @RepsForBiden: The world is laughing at you @realDonaldTrump \nUnfortunately, we all pay the price. https://t.co/es7BEnvuoo',
#  '@linkerstokoxu In germany it seems to work.. people still care, IN THE NETHERLANDS THOUGH 99% SEEMS TO BE MENTALLY DISABLED',
#  'pythonよりKuinが好き',
#  'RT @first_issues: Meeting screen, morale and luck sprites, sprites are not correctly centered horizontally with respect to ea… https://t.co…',
#  'RT @first_issues: Dismissed hero can be bought in tavern with his full army https://t.co/zzmKxWq5K0 #github #C++ #C #Python #Batchfile #Mak…',
#  'RT @techopcode: Internet of Things &amp; How Does It Work? #IoT Explained. #BigData #Analytics #DataScience #AI #MachineLearning #IIoT #Python…',
#  'RT @dataforpolicy: And we are back for the third and final #keynotelecture of #DataForPolicy2020. \n\nThis session is chaired by @chluetge fe…',
#  'RT @NancyJouwe: Ik geef binnenkort weer wat stadswandelingen in Utrecht en Amsterdam.\nOoit wandelde ik door Utrecht met Maarten v Rossem om…',
#  'RT @realtoughcandy: My 5th book Portfolio Surgery is dropping November 16! \n\nIt shows you 5 methods for making #software projects your own…',
#  'RT @realtoughcandy: My 5th book Portfolio Surgery is dropping November 16! \n\nIt shows you 5 methods for making #software projects your own…',
#  'RT @realtoughcandy: My 5th book Portfolio Surgery is dropping November 16! \n\nIt shows you 5 methods for making #software projects your own…',
#  'RT @RitupaGhosh: #IIT Kharagpur Researchers Use #ArtificialIntelligence to Predict Presence of Arsenic in Groundwater.\n@ram_tiwari_ @baski_…',
#  '@Matthijs85 lijkt me ook wel afd. participatie (of tegenwerken ervan)',
#  'RT @WHEFEvents: Join #WHEFEvents on the 4th December to discuss #evidence based #policymaking. We look forward to @drbrainbugz @Debbie_abra…',
#  'Python読みやすい、激しく同意できない',
#  'RT @STTHRILL: #FLYPE and #Phantasialand are trending in the Netherlands',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @ModiJiAt70: The Netherlands, a country in northwestern Europe, is known for a flat landscape of canals, tulip fields, windmills and cyc…',
#  'RT @themaxburns: Sen. @PattyMurray is asking Redfield what efforts CDC is taking to make sure all public health information given to the pu…',
#  '@officialmrdeen Holland, Netherlands, Switzerland',
#  'C++ std::fill with std::deque\nhttps://t.co/J53o2Cy72X\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/45RrfQnd9S',
#  'Zuid opent aanvraag voor vierjarige subsidieregeling kunst inschrijven kan tot 31 oktober. oa \u2066@OCCII_Amsterdam\u2069… https://t.co/nosv5PN9ev',
#  'RT @realtoughcandy: My 5th book Portfolio Surgery is dropping November 16! \n\nIt shows you 5 methods for making #software projects your own…',
#  'RT @pak_aims: The future growth of AI and ML #MachineLearning #artificialintelligence #learning via https://t.co/CkloYsjwog\nhttps://t.co/CK…',
#  'RT @IEFKUH: Whe love you to Mr President \nLove from the Netherlands for @realDonaldTrump ❤🙏🇺🇸',
#  'RT @cppsecrets: C++ std::fill with std::deque\nhttps://t.co/J53o2Cy72X\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #co…',
#  'RT @aminshergoraya: یہ دور اب artificial intelligence اور big data کا ہے اور یہاں جو ہم نے 5 چین کی اور 3 آسٹریا کی یونیورسٹیز سے collabora…',
#  'How Much Does It Cost To Make A Web App With Python?\n\n#Python #WebApp #PythonDeveloper \n\nhttps://t.co/VwXlfaBxLL',
#  '@pickle_rick6 @WSJ @SenSherrodBrown @RepMarciaFudge @senrobportman @GovMikeDeWine @LtGovHusted They’re not using sc… https://t.co/bFGsXoSFJt',
#  'RT @Gertsroyals: Queen Máxima of the Netherlands riding a bike while wearing a dress, in high heels &amp; a large hat, &amp; carrying her purse.…',
#  'RT @vuejsamsterdam: Vuejs Amsterdam 2021 will be FREE \nhttps://t.co/tMpQt9HmXR\n\nThanks to @isro_me from @passionpeopleNL who worked tireles…',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @mukundspeaks: Mukund earned a statement of accomplishment on DataCamp for completing Intermediate Python! https://t.co/HpHSzkmXGP via @…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/ydhqMgYkw1',
#  'RT @DevelopmentPk: PM Imran Khan inaugurated another flagship project of #KP Government, Pak-Austria Fachhochschule University, #Haripur. U…',
#  "@FrancescoCiull4 👋 Hi, I'm Jatin Varlyani \n🌐: Mumbai, India 🇮🇳 \n💼: Final year Btech Student \n👨\u200d💻: JS, Python, Node,… https://t.co/oLxdLpCdRz",
#  'RT @ryanstruyk: Confidence in President Trump in poll of 13 countries via \n@pewresearch:\n\n25% Japan\n23% Australia\n20% Canada\n19% United Kin…',
#  'Lijkt mij beter dat zij een andere job gaat zoeken want er blijft van onze hoofdstad Amsterdam op den duur niks mee… https://t.co/KNaFxGriLn',
#  '@Mg_Ante parang ang ganda nga nyang Data Science sir',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  '（私はデザイナー志望なので、やらないんですけれど…流行りのPythonのことを「ファイトン」と読んでました😅最近、それを「パイソン」と読むことを知りまして…めちゃくちゃ恥ずかしかった💦）',
#  'RT @AmadeusGrads: It’s not always easy to source #DataAnalytics skills. Speak to Amadeus about hiring one of our #SAScertified #graduates f…',
#  'RT @Datascience__: Machine Learning Mathematics: Study Deep Learning Through Data Science. How to Build Artificial Intelligence Through Con…',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @Hold2LLC: Imagine how much of this we AREN’T seeing. \n\nThink about places like CT (see chart), AZ (see charts), CA (impossible reopenin…',
#  '@officialmrdeen Iceland, Netherlands',
#  'RT @ModiJiAt70: The Netherlands, a country in northwestern Europe, is known for a flat landscape of canals, tulip fields, windmills and cyc…',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'New confirmed Covid cases in the Netherlands:\n16-9 +1766\n15-9 +1418\n11-9 +1270\n9-9 +1140\n8-9 +983\n7-9 +812\n11-8 +77… https://t.co/TZN09eVV4t',
#  'Attendez enfaite la Belgique ferme du coup pour aller à Amsterdam c’est mort 🤨😵',
#  'Matplotlib in Python \nhttps://t.co/0mqYy2tndp',
#  'Central Station Amsterdam\n17.09.2020 https://t.co/fXEnZqcqTz',
#  '14:37:04 P 1 Ongeval Wegvervoer Letsel Verlengde Stellingweg Amsterdam',
#  '14:37:04 P1 ongeval wegvervoer letsel verlengde stellingweg amsterdam',
#  'P 1 Ongeval Wegvervoer Letsel Verlengde Stellingweg Amsterdam https://t.co/kpYijsiGxn #p2000',
#  '🔴 #AMSTERDAM #AML 🚓 #p2000 \nP 1 Ongeval Wegvervoer Letsel Verlengde Stellingweg Amsterdam\n https://t.co/wqCbV9KNvt',
#  'P 1 Ongeval Wegvervoer Letsel Verlengde Stellingweg Amsterdam https://t.co/GvE1u77gkh #p2000',
#  '14:37:21u | P 1 Ongeval Wegvervoer Letsel Verlengde Stellingweg Amsterdam | Politie Amsterdam Persinformatie | ^TZ',
#  'RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…',
#  'Certainly a complex issue. I feel like we selling  away pieces of our soul. Our secrets; which invariably are consu… https://t.co/obrwtKfAe9',
#  'RADIO KLUB // Only the best House Music and Techno with the best DJs from Ibiza, London, Berlin, Amsterdam, Barcelo… https://t.co/jkDhbnBfIv',
#  '@DumoDenga Germany, Netherlands, Belgium... why does the minimum wage work so well in ALL THESE PLACES?',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/esiPvG0bud',
#  'RT @ana__freire: 📢Abierto el proceso de admisión al curso #Executive 🎓: 𝐀𝐩𝐫𝐨𝐱𝐢𝐦𝐚𝐜𝐢𝐨́𝐧 𝐩𝐫𝐚́𝐜𝐭𝐢𝐜𝐚 𝐚 #𝐃𝐚𝐭𝐚𝐒𝐜𝐢𝐞𝐧𝐜𝐞 𝐲 #𝐌𝐚𝐜𝐡𝐢𝐧𝐞𝐋𝐞𝐚𝐫𝐧𝐢𝐧𝐠, que impa…',
#  'RT @BroganRoganTrev: Europeans, in this case the Dutch, are as mad as hatters! Imagine pulling a stunt like this to encourage the old, the…',
#  'RT @MhamadHarmush: كتاب شامل لتعلم لغة Python من الصفر وصولاً لمستوى متقدم و الجميل فيه أيضاً أن يتطرق للتعامل معها مع نظام ويندوز, لينكس و…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'After not being able to defeat Protestantism in Germany, he moved to the Netherlands to fight viscously. The Dutch… https://t.co/QVyG1RSCvp',
#  'RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…',
#  'RT @Datascience__: Machine Learning Mathematics: Study Deep Learning Through Data Science. How to Build Artificial Intelligence Through Con…',
#  'RT @SOliver2020: Zaandam, Netherlands 🇳🇱 https://t.co/x2zQVUL56g',
#  'RT @KTIconnect: Artificial Intelligence is helping Irish business innovate and grow - Join @KTIconnect on 6th October to find out more abou…',
#  'C++ std::fill with std::vector\nhttps://t.co/ldWlB97rep\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus… https://t.co/Tbty3o6YrQ',
#  'RT @cyberpredator01: Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop #computerscie…',
#  'Nice. Weg met plezierkerken.',
#  'RT @three_cube: Python Basics for Hackers, Part 4: Finding the Exact Location of Any IP Address #python #python4hackers #scripting4hackers…',
#  'RT @alferdi: #BoneiruTinTwitter any Bonairians living in the Netherlands who feel like taking a FREE day trip on Sunday Sept 27 to the Bonn…',
#  'RT @RepsForBiden: The world is laughing at you @realDonaldTrump \nUnfortunately, we all pay the price.',
#  'We are ruled by tyrants. #Tyranny',
#  'RT @cppsecrets: C++ std::fill with std::vector\nhttps://t.co/ldWlB97rep\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #c…',
#  'RT @cppsecrets: C++ std::fill with std::vector\nhttps://t.co/ldWlB97rep\n\n#Cppsecrets #cppsecrets #python3 #python #cplusplus #programming #c…',
#  'RT @SOliver2020: Zaandam, Netherlands 🇳🇱 https://t.co/x2zQVUL56g',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'bro wtf the king and queen of the netherlands are in my town??&amp;/?:&amp;',
#  'RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.',
#  '.@The_IPO is calling for views on the implications #AI might have for #IP policy.\n\nFor more information and to shar… https://t.co/PByS54DkWp',
#  'it’s chilly in new york these days because the smoke from the wildfires has drifted to the east coast. it’s reached… https://t.co/QnNL8ZHcKT',
#  'Nee Amsterdam was niet zo leuk',
#  "'Heineken maakt met seltzer werk van klantgerichtheid': AMSTERDAM (AFN) - Heineken laat met de introductie van nieu… https://t.co/YjsaaTKsNF",
#  "Dat ik nog eens een link van Bij1 zou tweeten zeg... Hahaha.\n\nEnnieweetjes: als je z'n neus breekt krijg je gratis… https://t.co/xnhntntM9D",
#  'RT @EsperDoD: To modernize our capabilities, we have successfully secured funding for game-changing technologies such as artificial intelli…',
#  'It should be noted that Netherlands Antilles is NOT Swaziland.',
#  'RT @parool: Vanuit een huiskamer met acht gelovigen bouwde pastor Samuel Lee in de Bijlmer een kerkgenootschap op met vestigingen in zes la…',
#  'RT @_nasch_: Aprobado en tiempo récord y mi regalo para ustedes, gratis por tan sólo 3 días mi curso: Python sin fronteras. https://t.co/8w…',
#  'RT @LavieJanRoos: Als je het uiterts linker riool wil openen hoef je alleen maar een foto van Halsema te posten en erbij te zetten dat ze b…',
#  '@CJBowden1 @jtyler220 @randycorporon',
#  '@ScottLimbrick I love her! (The python)',
#  'RT @LavieJanRoos: Als je het uiterts linker riool wil openen hoef je alleen maar een foto van Halsema te posten en erbij te zetten dat ze b…',
#  'RT @FaisalJavedKhan: Prime Minister Imran Khan will inaugurate the KP Govt flagship project  Pak-Austria Fachhochschule University in Harip…',
#  'RT @looselipsevents: FEATURE - DnB Fix 030: Artificial Intelligence - No Choice\n\nhttps://t.co/AjH5k5QotC\n\nYep, it’s that time of the week a…',
#  'GLOBAL SENIOR MARKETING MANAGER wanted for the global headquarters of one of the leading global music agencies in t… https://t.co/Zjpdvveqkh',
#  'RT @fperez_org: Numpy @numpy_team is the foundational layer that supports the entire Scientific Python ecosystem. Congrats to the team for…',
#  'RT @PTIofficial: PM @ImranKhanPTI inaugurated another flagship project of KP Government, Pak-Austria Fachhochschule University, Haripur. Un…',
#  '#programming #programmer #Python #javascript #NodeJS @javascriptflx @Anon_ITALY_ @elimone \n@0x5t3x1_N @abu7ala1… https://t.co/qDrgG63g4I',
#  'RT @three_cube: Python Basics for Hackers, Part 4: Finding the Exact Location of Any IP Address #python #python4hackers #scripting4hackers…',
#  'Click on below link to read...\n\nhttps://t.co/R8733RsYt8\n\n#computer #technology #pc #tech #gaming #laptop… https://t.co/PYyuzXoknG',
#  'RT @amacomonline: GLOBAL SENIOR MARKETING MANAGER wanted for the global headquarters of one of the leading global music agencies in the wor…',
#  'RT @olgatuleninova: "Peasant Woman Binding Sheaves".(1889)\nBy Vincent van Gogh.Dutch post-impressionist\nVan Gogh Museum. Amsterdam https://…',
#  "RT @venikunche: #TechTwitter - Let's amplify Sia, please! \n\nSia is looking for a Data Science role. She has an MS in Data Analytics &amp; Appli…",
# ...
#  'Amsterdam, student cities face new coronavirus clampdown as infections soar https://t.co/vjjXJU6OCt',
#  'RT @archangeljf12: Artificial intelligence program used against ISIS now used by DNC against Trump &amp; supporters online https://t.co/qZZsSTe…',
#  'Thank you for listening to science FWISD Trustees Ramos, Paz, Phillips and Luebanos',
#  'RT @heySushil: #Day 31 #final #stage of #test #cases #on #Django #Framework\n#heysushil #100DaysOfCode #Python #Python3 #DeepLearning #webde…',
#  'RT @aakashns: A Jupyter extension to turn plain English into Pandas code, a new MIT course on Computational thinking in Julia, and a tutori…',
#  'RT @MilHistNow: On this day in 1944, the first of 41,000 Allied paratroopers are dropped into the Netherlands as part of the ill-fated Oper…',
#  '@hkmoon87 @HassaninDC @ConservBlue2020 @phoenix66101281 The CDC unequivocally advocates for the use of masks as an… https://t.co/HzlzRz7irP',
#  "RT @MicrosoftUK: It's National Coding Week here in the UK! \n\nWhether you are a C# student or a Python pro, it's never too late to brush up…",
#  'RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.',
#  'RT @RutgervdNoort: Schiphol 17-09-2020, Chinezen wachtend op @KLM-vlucht van Amsterdam naar Venetië. (Bron: via vriend) https://t.co/B5s4x4…',
#  "@Ash3Dot0 @StanMourdon en l'occurence c'est pas un site c'est une app en python et l'interface est avec tkinter",
#  "How can I improve my code readability? Spaghetti Code (I'm a beginner) https://t.co/XDbEjTy6aK #readability… https://t.co/GE64bxqUck",
#  'RT @CardioIAN: In the US I\'m most of the time the tallest in the "group", 6ft. People keep telling me, the Dutch are so tall. Today the pro…',
#  '@LavieJanRoos En je geslacht, en je bent kansloos, dat allemaal in 3 woorden! Universitair niveau in Amsterdam.',
#  'My 2 days off on monday and tuesday got canceled, because a colleague is on his vacation in the Netherlands. The re… https://t.co/7ovxwI2wvJ',
#  'RT @DD_Wen_: R for Data Science: Import, Tidy, Transform, Visualize, and Model Data https://t.co/IhMRSWlfxs #DataScience',
#  "RT @Projet_Arcadie: Être député européen.\nNe pas savoir ou feindre de ne pas savoir que l'abolition de la peine de mort est une condition n…",
#  'Update #corona #kaart\n•  1700+ positieve tests\n• 86 (+9 !) gemeentes 🔴\n• #Amsterdam weer verder omhoog (nieuwe kleu… https://t.co/bsZhjOn2RC',
#  'Eli Lilly says antibody drug ‘may reduce hospitalisations’ for Covid-19\n\nInterim trial data suggests the experiment… https://t.co/22UgUwQ0dS',
#  'RT @HexletHQ: Друзья, мы ищем наставников в Хекслет и запускаем реферальную систему. В рамках нее мы будем выплачивать по $60 за каждую уда…',
#  'RT @archangeljf12: Artificial intelligence program used against ISIS now used by DNC against Trump &amp; supporters online',
#  'RT @Gertsroyals: Queen Máxima of the Netherlands riding a bike while wearing a dress, in high heels &amp; a large hat, &amp; carrying her purse.…',
#  'im sure i can do it',
#  'https://t.co/3OYLQkfkFE',
#  'RT @PlymouthMarine: How can we find new ways to communicate climate science? Dr @LeedeMora &amp; his team have developed a technique for turnin…',
#  'And over here we are paying just under £70 for a return ticket from Wrexham to Cardiff on past their sell-by date t… https://t.co/UjKlIAD6bP',
#  'RT @YahboomT: Hi~ \nOmniduino🚜, G1 Tank🚄, Jetbot🏍️, Mbit car🚓. \nThey all come from Yahboom. Who is your favorite?😍\nhttps://t.co/2CZiOhHSWj…',
#  "RT @raiomido: How to become a Python Web Developer.\n\nLet's explore a possible path to take to become a well-seasoned Python web developer.…",
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @ZweigKristin: What are the best CMS for Python? \n\nhttps://t.co/M9EY3lXo9e \n\n#Python #Developer #CMS https://t.co/c1jvQqxLd5',
#  'RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.',
#  'RT @KirkDBorne: Object Detection with 10 lines of code: https://t.co/q4LPOzCbwI\n——————\n#BigData #DataScience #AI #MachineLearning #DeepLear…',
#  '@panic Guys, why autocomplete in ts or python is so bad? Like there’s no lsp in it',
#  '@ClarenceHouse   https://t.co/H4IfSv6kl0 On Oct.29, 2014, The Imperial Banquet was held at the Imperial Palace invi… https://t.co/gYm2Mlp2VE',
#  'RT @Hold2LLC: Imagine how much of this we AREN’T seeing. \n\nThink about places like CT (see chart), AZ (see charts), CA (impossible reopenin…',
#  '@BBhuttoZardari \nhttps://t.co/E4GiDnzg96 - admin',
#  'RT @glenannefilm: A huge rise in DVD requests internationally after last night’s screening. This batch posting to Australia, US, Netherland…',
#  "RT @UberFacts: In 2013, 19 prisons in the Netherlands closed because the country didn't have enough criminals to fill them.",
#  'AI 100: The Artificial Intelligence Startups Redefining Industries @CBinsights #healthcare #healthtech #fintech… https://t.co/mUozm7gxDB',
#  'Gente, não briguem comigo. Não é preconceito contra o pessoal mais velho. \n\nVou repetir: o CEO da Netflix tem só 7… https://t.co/kUW7eY4iRD',
#  'RT @sergey_e_kim: Amsterdam 1970. Another division of the first place with the world champion (1969 with Petrosyan the USSR championship) I…',
#  '@IntlCrimCourt @UWindsor @WindsorLaw Remove the @HogeRaad from The Netherlands with their organ the @nos it is raci… https://t.co/aw8JYpE96o',
#  'Nobody really cares about your story till you succeed,  so succeed and make it happen. \n#techthursday\n#sucessstory… https://t.co/I1JNr0DJW9',
#  'RT @tractable_ai: A must-read: how our #AI is changing the game for analysing and understanding auto damage, featured today in @nytimes and…',
#  'RT @ianmSC: Nashville’s case numbers in bars and restaurants were so low they literally were emailing each other about how best to hide tha…',
#  'RT @JohdaGAWD: Un an que le métro d’Amsterdam n’est pas passé',
#  'RT @EduMinOfIndia: .@Microsoft in association with @nasscom will offer AI, #MachineLearning &amp; data science expertise to students through ea…',
#  'RT @CircuitPython: ICYMI Python on Microcontrollers Newsletter: Over 200 CircuitPython compatible boards! #Python #Adafruit #CircuitPython…',
#  'RT @yaso: Gente, não briguem comigo. Não é preconceito contra o pessoal mais velho. \n\nVou repetir: o CEO da Netflix tem só 7 anos a mais q…',
#  'RT @adafruit: ICYMI Python on Microcontrollers Newsletter: Over 200 CircuitPython compatible boards! #Python #Adafruit #CircuitPython #ICYM…',
#  'RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.\nRotterdam-Amsterdam: 75 km, 45 minuts en tren\nManresa-Barcelona: 60 km, 1h 30 en tren.\nUt…',
#  'RT @BGS_ScienceDpt: Year 5C have been testing their data collection and graph drawing abilities in Science #BGSScience https://t.co/E9NP3dl…',
#  'RT @AlexFleischer1: #CPLEX @IBM reminder : Many options for running an #OPL model : On #prem , on a #server and in the #wml #cloud . In the…',
#  'Artificial Intelligence for Colorists - https://t.co/shrkb6ki4H https://t.co/Thvji7aL79',
#  '@artcrimeprof Great subject!!!   Let’s think a bit.   Bavaria, Switzerland and the Netherlands (Menten) were and st… https://t.co/N5DfpkPBPn',
#  'Operation Market Garden, an Allied airborne and ground operation in the Netherlands, begins, 17 September 1944. #OTD https://t.co/whbYTQPOo8',
#  'RT @_nasch_: Aprobado en tiempo récord y mi regalo para ustedes, gratis por tan sólo 3 días mi curso: Python sin fronteras. https://t.co/8w…',
#  '@FrancescoCiull4 👋: Olhighjay\n🌐: Lagos, Nigeria\n💼: Backend stack\n💎: PHP, JS, Jquery, Python\n💙: solving problems',
#  'RT @thepythonquiz: Which one is the parent class?\n\nOSError\n\nTimeoutError\n\n#python #python3 #pythonprogramming #learnpython',
#  'me morc no puc més 😭😭😭😭😭',
#  'RT @Jeff66923777: SCIENTIFIC AMERICAN magazine has endorsed @JoeBiden.\n\n"The evidence &amp; the science show that Donald Trump has badly damage…',
#  'RT @_M_Dey: Artificial intelligence for the recovery of essential body functions - @InnoOrigins - Innovation Origins | #AI #MachineLearning…',
#  'RT @archangeljf12: Artificial intelligence program used against ISIS now used by DNC against Trump &amp; supporters online',
#  'RT @TechParida: 6 Ways to Format a String in Python💕\n\n#100DaysOfCode #CodeNewbies https://t.co/nWYFbKtAd1',
#  '#programming #programmer #Python #javascript #NodeJS @PhishFindR @javascriptflx @Anon_ITALY_ @elimone \n@0x5t3x1_N… https://t.co/YA88v46ak1',
#  "RT @adamdriscoll: I'm starting to learn more Python, so I put together to #PowerShell vs #Python Reference post to compare the various aspe…",
#  '@zaggleapp Zaggle deploys cutting edge technologies AI (Artificial Intelligence), ML (Machine Learning) and OCR (Op… https://t.co/Az2N6soarT',
#  'RT @Mboschm: Vic-Barcelona: 80 km, 1h 30 en tren.\nRotterdam-Amsterdam: 75 km, 45 minuts en tren\nManresa-Barcelona: 60 km, 1h 30 en tren.\nUt…',
#  'Mentoring sessions, bootcamps, virtual training… The #CopernicusAccelerator 2020 has it all! The… https://t.co/ShulnsgF79',
#  'Discriminative Model - Machine Learning Glossary ?\n\n#primeclasses #datascience #Python #libraries #machinelearning… https://t.co/hYlGstVjPe',
#  'RT @PebbzPR: @lisarinna forgot the secret w HarryHamlin that you fought Kim over? Amsterdam dinner frm hell? What were YOU hiding?Yall need…',
#  'WHAT IS THE FUTURE OF ARTIFICIAL INTELLIGENCE IN CLINICAL RESEARCH? https://t.co/qjH8En09uV \n#artificialintellegence #AI #clinicalresearch',
#  '4) Artificial Intelligence and Human Ingenuity: Better Together - 4 major #mrx themes at #IIeXNA… https://t.co/x95S8pibU8',
#  'RT @42Sz40: #programming #programmer #Python #javascript #NodeJS @PhishFindR @javascriptflx @Anon_ITALY_ @elimone \n@0x5t3x1_N @abu7ala1 #li…',
#  'RT @glitchbotio: "Repetition does not transform a lie into a truth."- Franklin D. Roosevelt #softwareengineer #javascript #python #C++ #gol…',
#  'RT @42Sz40: #programming #programmer #Python #javascript #NodeJS @PhishFindR @javascriptflx @Anon_ITALY_ @elimone \n@0x5t3x1_N @abu7ala1 #li…',
#  "RT @Bachvereniging: Onder toeziend oog van Rembrandts 'De Nachtwacht' speelt Richard Egarr het Concert in D groot, BWV 972. Uitgevoerd op e…",
#  'RT @PrimeClasses_: Discriminative Model - Machine Learning Glossary ?\n\n#primeclasses #datascience #Python #libraries #machinelearning #arti…',
#  'Dark side of #AI: How to make artificial intelligence trustworthy. https://t.co/4JB4okfnqz? @avivahl @Gartner_inc… https://t.co/Gasvfzjuq7',
#  'Something hilarious about waiting for the the 25th anniversary (according to Wikipedia) of your library before writ… https://t.co/g8ITZil5zL',
#  'RT @PrimeClasses_: Discriminative Model - Machine Learning Glossary ?\n\n#primeclasses #datascience #Python #libraries #machinelearning #arti…',
#  'RT @prirani103: it’s chilly in new york these days because the smoke from the wildfires has drifted to the east coast. it’s reached as far…',
#  'https://t.co/R62qULJ3oA #machinelearning KDnuggets™ News 20:n35, Sep 16: Data Science Skills: Core, Emerging, and M… https://t.co/IiNgCYP8Ew',
#  'Learn data science and develop a profession that is important both now and in the future. The python language is on… https://t.co/GjVOIl8GsQ',
#  'RT @Dutchy_in_Spain: *GRATIS OP TE HALEN IN AMSTERDAM*\nGrenen eettafel - zeer goede staat - 185x90 \nTot en met maandag af te halen \n(Dus al…',
#  'RT @nicktea: We never sleep 😴 #hackers #hacking #hacker #cybersecurity #ethicalhacking #hack #kalilinux #linux #programming #technology #an…',
#  'RT @glitchbotio: "Repetition does not transform a lie into a truth."- Franklin D. Roosevelt #softwareengineer #javascript #python #C++ #gol…',
#  'This Hours Photo: #weather #minnesota #photo #raspberrypi #python https://t.co/sXN67PAbO9',
#  "@CreedWTF @sniperiwnl 😂😂😂, I can't find a study here in the netherlands to find out how to join OT",
#  "RT @Republic_Bharat: मैनचेस्टरः अजगर को 'फेस-मास्क' की तरह पहने नजर आया बस यात्री, लोग रह गए हैरान\nhttps://t.co/3qcSnwcfJR",
#  '@Kingslayer_Vj @actorvijay "Twitter Polls Manipulation #Python #Selenium #Twitter #Hack #Bots - YouTube"… https://t.co/x7G2zdD9Yj',
#  '[Guidelines] Programming for Beginners!\n.\n.\n.\n.\n.\nhttps://t.co/uBvXSlkOmU\n\n#BigData #Analytics #DataScience… https://t.co/5qWL1sVsZ1',
#  'RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.',
#  'RT @TheRottenOaks: First live chat streaming in the Netherlands!\nCome join the crew of the Rotten oaks for a chill and a brew! \n!subanims a…',
#  'RT @ZweigKristin: How Much Does It Cost To Make A Web App With Python?\n\n#Python #WebApp #PythonDeveloper \n\nhttps://t.co/VwXlfaBxLL',
#  "RT @UberFacts: In 2013, 19 prisons in the Netherlands closed because the country didn't have enough criminals to fill them.",
#  '@FtblLuqy And hopefully Gini Plays like he used to with Netherlands',
#  'RT @ryanstruyk: Confidence in President Trump in poll of 13 countries via \n@pewresearch:\n\n25% Japan\n23% Australia\n20% Canada\n19% United Kin…',
#  'RT @testdrivenio: Building Your Own Python Web Framework\n\nLearn how to:\n\n🔹Build your own WSGI-compliant web framework\n🔹Develop function and…',
#  '#Netherlands comes in with yet another #Covid19 national daily record\n\n1,753 new cases. 6 new deaths.\n\nRemember I e… https://t.co/uudOUiqlfb',
#  'RT @WOFES3WAGYIMI: BROTHERS BUT DIFFERENT NATIONAL TEAMS\n\nPaul Pogba (France 🇨🇵)\nFlorentin Pogba (Guinea 🇬🇳)\nMathias Pogba (Guinea 🇬🇳)\n\nChr…',
#  'RT @mygovindia: Are you an AI enthusiast and you think your innovative AI solution has the power to solve societal challenges? Then we have…',
#  'RT @ProgrammingHero: [Guidelines] Programming for Beginners!\n.\n.\n.\n.\n.\nhttps://t.co/uBvXSlkOmU\n\n#BigData #Analytics #DataScience #DeepLearn…',
#  'RT @ProgrammingHero: [Guidelines] Programming for Beginners!\n.\n.\n.\n.\n.\nhttps://t.co/uBvXSlkOmU\n\n#BigData #Analytics #DataScience #DeepLearn…',
#  'Zaggle deploys cutting edge technologies AI (Artificial Intelligence), ML (Machine Learning) and OCR (Optical Chara… https://t.co/IT7MsNscaf',
#  'RT @VoltAfrica: Do you think that Artificial Intelligence is changing the digital marketing game? #ThursdayThoughts #UnlockYourVolt',
#  'RT @ProgrammingHero: [Guidelines] Programming for Beginners!\n.\n.\n.\n.\n.\nhttps://t.co/uBvXSlkOmU\n\n#BigData #Analytics #DataScience #DeepLearn…',
#  'RT @ProgrammingHero: [Guidelines] Programming for Beginners!\n.\n.\n.\n.\n.\nhttps://t.co/uBvXSlkOmU\n\n#BigData #Analytics #DataScience #DeepLearn…',
#  'RT @DevelopmentPk: PM Imran Khan inaugurated another flagship project of #KP Government, Pak-Austria Fachhochschule University, #Haripur. U…',
#  'RT @peteskomoroch: What mistakes do you often see data science teams make when computing and reporting metrics? Where do they waste the mos…',
#  'RT @justin_hart: Mark my words. Nearly every lockdown jurisdiction will be facing the music on this issue soon.',
#  'RT @TUUR1: @olimpiuurcan @Grukjr Like Agdestein Soos played football at a high level. The 1962 Russian Yearbook says he had been player of…',
#  'RT @FunmiOwolabi2: What is the best way to handle missing values in a data set?\n#Python #MachineLearning #100DaysOfCode #CodeNewbies',
#  'RT @PrimeClasses_: Discriminative Model - Machine Learning Glossary ?\n\n#primeclasses #datascience #Python #libraries #machinelearning #arti…',
#  '9.16일의 수확\n: Python은 camel case를 선호하지 않는다.',
#  'RT @Entrepreneurix: https://t.co/iCp84jD95x\n\nPicture of #StefBlok and Joseph Borrell makes you understand why the Dutch Minister of Foreign…',
#  'RT @prirani103: it’s chilly in new york these days because the smoke from the wildfires has drifted to the east coast. it’s reached as far…',
#  'RT @FunmiOwolabi2: What is the best way to handle missing values in a data set?\n#Python #MachineLearning #100DaysOfCode #CodeNewbies',
#  '10 Things You Didn’t Know About Scikit-Learn #data #kdnuggets #scikitlearn #python https://t.co/NSeUIpk0cc',
#  ...]

# %% [markdown]
# We can notice that the data is very noisy. It contains a lot of html artifacts, emojis, links and even extra metadata that we do not need at this time or it obstructs the clarity of the content in the tweet.
#
# In cases like these, a preprocessing step is required before analysis can be performed.
#
# As a first step in this direction we will structure the tweets data into a pandas DataFrame to simplify the data manipulation. We will start by creating an empty DataFrame called tweets and we will add 3 columns to the tweets DataFrame called text, lang, and country. text column contains the tweet, lang column contains the language in which the tweet was written, and country the country from which the tweet was sent.

# %% [markdown]
# #### This step can take a minute or two

# %%
import pandas as pd

tweets = pd.DataFrame()

tweets['text'] =    list(map(lambda tweet: tweet['text'], tweets_data))
tweets['lang'] =    list(map(lambda tweet: tweet['lang'], tweets_data))
tweets['country'] = list(map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data))

# %% [markdown]
# Next, we will create 2 charts
# + The first one describing the Top 5 languages in which the tweets were written
# + The second the Top 5 countries from which the tweets were sent.
#
# We will create these two charts using MatPlotLib (the library we installed in the begining of the assignment).

# %%
import matplotlib.pyplot as plt

# This is a directive that enables displaying charts in iPython notebooks.
# %matplotlib inline


tweets_by_lang = tweets['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

# %% [markdown]
# We can do the same thing for countries:

# %%
#Note - many times no country is scored, so you might have very few entries in this histogram (perhaps none or 1)

tweets_by_country = tweets['country'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Countries', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
tweets_by_country[:5].plot(ax=ax, kind='bar', color='blue')

# %% [markdown]
# ### Food for thought
#
# There are plenty of ways the gathered data can be skewed and manipulated a false image about something. This is a technique used in marketing very often. Can you think of ways to prove the statistic we displayed in the previos section as biased?

# %% [markdown]
# ### Extracting links from tweets
#
# Tweets very often carry additional context information to the statement they are making in a hyperlink. Extracting these hyperlinks from the tweets might provide an expansion for thte dataset you are collection or analyzing. A usefull skill in data science is to extract this type of information. We will do this by using regular expressions. Python provides a library for regular expression called re.
#
# We will start by importing this library and creating a function that checks if a specific keyword is present in a text and a second function that extracts the hyperlink from a the tweets content.

# %%
import re

# A function that extracts the hyperlinks from the tweet's content.
def extract_link(text):
    regex = r'https?://[^\s<>"]+|www\.[^\s<>"]+'
    match = re.search(regex, text)
    if match:
        return match.group()
    return ''

# A function that checks whether a word is included in the tweet's content
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

# %% [markdown]
# Next we add a column to our predifined Data Frame with:

# %%
tweets['link'] = tweets['text'].apply(lambda tweet: extract_link(tweet))

# %% [markdown]
# With the help of this frame we can then print all the links from the tweets that we gathered and show them on the screen below:

# %%
print(tweets['link'])

# %% [markdown]
# **Removing Hyperlinks**
#
# An additional use case that comes up from detecting the hyperlinks in the tweets is their removal. When subjecting the tweet's content to tokenization of mapping it with some sort of an embedding, it is recomended that artifacts like hyperlinks be removed first.

# %% [markdown]
# #### You have to define your own 'index_in_dataframe_containing_link'. Pick one of the non-null entries above from "print(tweets['link'])"

# %%
index_in_dataframe_containing_link = 0
unescaped_tweet = tweets_data[index_in_dataframe_containing_link]['text']
# With link in the content
print("With link:\n", unescaped_tweet)

# With the link removed
result = re.sub(r"http\S+", "", unescaped_tweet)
print ("\n\nLink free:\n",result)

# %% [markdown]
# ### Tokenization
#
# **Definition**: Tokenization is the process of demarcating and possibly classifying sections of a string of input characters. The resulting tokens are then passed on to some other form of processing. The process can be considered a sub-task of parsing input.

# %%
from nltk.tokenize import RegexpTokenizer
import html.parser as HTMLParser# In Python 3.4+ import html 
import nltk

tokenizer = RegexpTokenizer(r'\w+')

dirty_tweet_tokens = tokenizer.tokenize(unescaped_tweet.lower())

cleaned_tweet_tokens = tokenizer.tokenize(result.lower())

print("Clean tokens:\n", cleaned_tweet_tokens)

print("\n\nDirty tokens:\n", dirty_tweet_tokens)

# %%
print("Actually got to this point and understood everything(!!!)")

# %% [markdown]
# You can notice that the tokens we get from the tweet containing the url have data that is not relevant to natural language and therfore any further analysis based on that.

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# **Sentiment Analysis** is the process of determining whether a piece of writing is positive, negative or neutral. It’s also known as opinion mining, deriving the opinion or attitude of a speaker. A common use case for this technology is to discover how people feel about a particular topic.
#
# There are two general directions in which you can steer your sentiment analysis pipeline:
# + Lexicon Based Approaches
# + Machine Learning Approaches
#
# #### A Basic Machine Learning Approach
#
# NLTK comes with all the pieces you need to get started on sentiment analysis: a movie reviews corpus with reviews categorized into pos and neg categories, and a number of trainable classifiers. We’ll start with a simple NaiveBayesClassifier as a baseline, using boolean word feature extraction.
#
# **What is a Classifier?**
#
# Wikipedia says: "<span style='color:red'>An algorithm that implements classification, especially in a concrete implementation, is known as a classifier. The term "classifier" sometimes also refers to the mathematical function, implemented by a classification algorithm, that maps input data to a category.</span>"
#
# It is basically a computer program that learns how to map a certain input to a certain output. It is able to translate the data in the input space into a different segmented output space, where each datum belongs its own dimension. For our example we are going to use the Naive Bayes classifier. This classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature. This makes this classifier simple and easy to use, however in a limitation of Naive Bayes is the assumption of independent predictors. In real life, it is almost impossible that we get a set of predictors which are completely independent.
#
# So before we start doing anything we need a ready corpus of data we can use to demonstrate the concept of Sentiment Analysis.

# %%
# This snippet downloads the most popular datasets for experimenting with NLTK functionalities.
import nltk
nltk.download('popular')

# %% [markdown]
# As a first step we import the required NLTK modules and define a simple function that is going to extract our features:

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews


# A function that extracts which words exist in a text based on a list of words to which we compare.
def word_feats(words):
        return dict([(word, True) for word in words])

# Get the negative reviews for movies    
negids = movie_reviews.fileids('neg')

# Get the positive reviews for movies
posids = movie_reviews.fileids('pos')
 
# Find the features that most correspond to negative reviews    
negfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in negids]

# Find the features that most correspond to positive reviews
posfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in posids]

# We would only use 1500 instances to train on. The quarter of the reviews left is for testing purposes.
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)

# %%
# Construct the training dataset containing 50% positive reviews and 50% negative reviews
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]

# Construct the negative dataset containing 50% positive reviews and 50% negative reviews
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]

print ('train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats)))

# Train a NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(trainfeats)

# Test the trained classifier and display the most informative features.
print ('accuracy:', nltk.classify.util.accuracy(classifier, testfeats))
classifier.show_most_informative_features()

# %% [markdown]
# ### Tweets Example
#
# The previous was somewhat large scale. We had a dataset fo 2000 film reviews. A smaller tweet dataset would better serve our cause. See example below:

# %%
# For this example we define our own dataset of 5 positive and 5 negative tweets.

# Positive tweets and their sentiment label
pos_tweets = [('I love this car', 'positive'),
              ('This view is amazing', 'positive'),
              ('I feel great this morning', 'positive'),
              ('I am so excited about the concert', 'positive'),
              ('He is my best friend', 'positive')]

# Negative tweets and their sentiment label
neg_tweets = [('I do not like this car', 'negative'),
              ('This view is horrible', 'negative'),
              ('I feel tired this morning', 'negative'),
              ('I am not looking forward to the concert', 'negative'),
              ('He is my enemy', 'negative')]

# The list of tweets we are going to use for testing (groundtruth)
test_tweets = [(['feel', 'happy', 'this', 'morning'], 'positive'),
    (['larry', 'friend'], 'positive'),
    (['not', 'like', 'that', 'man'], 'negative'),
    (['house', 'not', 'great'], 'negative'),
    (['your', 'song', 'annoying'], 'negative')]

# %% [markdown]
# We take both of those lists and create a single list of tuples each containing two elements. First element is an array containing the words and second element is the type of sentiment. We get rid of the words smaller than 2 characters and we use lowercase for everything.

# %%
# pprint is a module for pretty printing
from pprint import pprint


tweets = []

# In this for loow we create a list of tuples like: (word_longer_than_3_letters, sentiment_label)
for (words, sentiment) in pos_tweets + neg_tweets:
    words_filtered = [e.lower() for e in words.split() if len(e) >= 3]
    tweets.append((words_filtered, sentiment))

# Printing how our dataset looks like after we have performed our own 'custom' tokenization of the tweets.
print("### Training examples ###\n")
pprint(tweets)

print("\n\n### Testing examples ###\n")
pprint(test_tweets)

# %% [markdown]
# Exactly like the example above, we define two functions. One for extracting the list of words in our tweet corpora and a second one to get the features on which we will train a classifier. In this case, our features would be the word appearance frequencies.

# %%
# Get the separate words in tweets
# Input:  A list of tweets
# Output: A list of all words in the tweets
def get_words_in_tweets(tweets):
    all_words = []
    for (words, sentiment) in tweets:
        all_words.extend(words)
    return all_words

# Create a dictionary measuring word frequencies
# Input: the list of words
# Output: the frequency of those words apearing in tweets
def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    print ("Word frequency list\n")
    pprint(wordlist)
    return word_features

# %% [markdown]
# To create a classifier, we need to decide what features are relevant. To do that, we first need a feature extractor. The one we are going to use returns a dictionary indicating what words are contained in the input passed. Here, the input is the tweet. We use the word features list defined above along with the input to create the dictionary.
#
# With our feature extractor, we can apply the features to our classifier using the method apply_features. We pass the feature extractor along with the tweets list defined above.

# %%
word_features = get_word_features(get_words_in_tweets(tweets))

# Construct our features based on which tweets contain which word
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %% [markdown]
# As you can see, **‘this’** is the most used word in our tweets, followed by **‘car’**, followed by **‘concert’**…
#
# The variable ‘training_set’ contains the labeled feature sets. It is a list of tuples which each tuple containing the feature dictionary and the sentiment string for each tweet. The sentiment string is also called ‘label’.

# %%
# Here we apply the features we constructed to our tweets data.
training_set = nltk.classify.apply_features(extract_features, tweets)

# Printing the resulting training set shows the features we are going to pass to the classifier.
pprint(training_set)

# %% [markdown]
# Now that we have our training set, we can train our classifier like in the previous example.

# %%
# This is the line of code that we use to train our classifier. Training is performed in a streamlined way so no output is visible.
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# The Naive Bayes classifier uses the prior probability of each label which is the frequency of each label in the training set, and the contribution from each feature. In our case, the frequency of each label is the same for ‘positive’ and ‘negative’. The word ‘amazing’ appears in 1 of 5 of the positive tweets and none of the negative tweets. This means that the likelihood of the ‘positive’ label will be multiplied by 0.2 when this word is seen as part of the input.
#
# So in our dataset the probability of each label is 0.5 as we can see below.
#
# ### <span style='color:red'>**Interesting observation**</span>
#
# If we observer the output of the function below, an interesting observation jumps out. Line one of the output has this content:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;contains(not) = False          positi : negati =      1.6 : 1.0
#
# This line tells us that if a tweet doesn't contain the word not **(contains(not) = False)** than it is 60% more likely to be positive than negative visible in: **(positi : negati = 1.6 : 1.0)**.

# %%
print (classifier.show_most_informative_features(32))

# %% [markdown]
# Now having seen the feature distribution for our data we can see how our classifier behaves in a real scenario where we apply it to a tweet it ahs not seen before and is not a part of the train or test set.
#
# If our tweet is:
# ** Larry is my friend **
#
# We would expect that the attributed sentiment would be: **positive**

# %%
# The tweet we are about to classify
tweet = 'Larry is my friend'
print (classifier.classify(extract_features(tweet.split())))

# %% [markdown]
# On the other hand if our tweet is: **This dish is horrible**
#
# We would expect that the attributed sentiment would be: **negative**

# %%
# The tweet we are about to classify
tweet = 'This dish is horrible'
print (classifier.classify(extract_features(tweet.split())))

# %% [markdown]
# However our simple classifier, trained on just 10 tweets is easy to fool. For example we have not encountered the word **horrendous**. So if our tweet would be:
#
# **Ivo listens to horrendous electronic music.**
#
# We would not know what to expect.

# %%
tweet = 'Ivo listens to horrendous electronic music'
print (classifier.classify(extract_features(tweet.split())))

# %% [markdown]
# In our case, the simple classifier made a mistake.

# %% [markdown]
# ## Topic Modeling
#
# One technique for text mining in Data Science is Topic Modelling. As the name suggests, it is a process to automatically identify topics present in a text object and to derive hidden patterns exhibited by a text corpus. Thus, assisting better decision making.
#
# Topic Modelling is different from rule-based text mining approaches that use regular expressions or dictionary based keyword searching techniques. It is an unsupervised approach used for finding and observing the bunch of words (called “topics”) in large clusters of texts.
#
# Topics can be defined as “a repeating pattern of co-occurring terms in a corpus”. A good topic model should result in – “health”, “doctor”, “patient”, “hospital” for a topic – Healthcare, and “farm”, “crops”, “wheat” for a topic – “Farming”.
#
# Topic Models are very useful for the purpose for document clustering, organizing large blocks of textual data, information retrieval from unstructured text and feature selection. For Example – New York Times are using topic models to boost their user – article recommendation engines. Various professionals are using topic models for recruitment industries where they aim to extract latent features of job descriptions and map them to right candidates. They are being used to organize large datasets of emails, customer reviews, and user social media profiles.
#
# ### What is Latent Dirichlet Allocation (LDA)?
#
# There are many approaches for obtaining topics from a text such as – Term Frequency and Inverse Document Frequency. NonNegative Matrix Factorization techniques. Latent Dirichlet Allocation is the most popular topic modeling technique and in this article, we will discuss the same.
#
# LDA assumes documents are produced from a mixture of topics. Those topics then generate words based on their probability distribution. Given a dataset of documents, LDA backtracks and tries to figure out what topics would create those documents in the first place.
#
# LDA is a matrix factorization technique. In vector space, any corpus (collection of documents) can be represented as a document-term matrix.
#
#
#
# ### LDA Parameters
#
# Alpha and Beta Hyperparameters – alpha represents document-topic density and Beta represents topic-word density. Higher the value of alpha, documents are composed of more topics and lower the value of alpha, documents contain fewer topics. On the other hand, higher the beta, topics are composed of a large number of words in the corpus, and with the lower value of beta, they are composed of few words.
#
# Number of Topics – Number of topics to be extracted from the corpus. Researchers have developed approaches to obtain an optimal number of topics by using Kullback Leibler Divergence Score. I will not discuss this in detail, as it is too mathematical. For understanding, one can refer to this[1] original paper on the use of KL divergence.
#
# Number of Topic Terms – Number of terms composed in a single topic. It is generally decided according to the requirement. If the problem statement talks about extracting themes or concepts, it is recommended to choose a higher number, if problem statement talks about extracting features or terms, a low number is recommended.
#
# Number of Iterations / passes – Maximum number of iterations allowed to LDA algorithm for convergence.
#
#
# ### Sample Topic Modeling Assignment
#
# As step one of this assignment we will construct our own dataset containing 5 documents on different topics like below:

# %%
doc1 = "Working out is great for the body. Fitness makes you feel good."
doc2 = "Red cars are faster than blue cars."
doc3 = "Doctors suggest that fitness increases muscle mass and speeds up metabolism."
doc4 = "Cars with electrical engines cause less polution than cars with internal combustion engines."
doc5 = "Pushups make a good upper body excercise."

# compile documents
doc_complete = [doc1, doc2, doc3, doc4, doc5]

# %% [markdown]
# We already noted that cleaning is an important step before any text mining task, in this step, we will remove the punctuations, stopwords and normalize the corpus. This makes it suitable for further analysis.
#
# We introduced the word <i>stopwords</i>. Stopwords are words that are filtered out before any analysis of natural language in order to increase efficiency and remove clutter. Examples of stop words are:
# + and
# + there
# + want
# + thus
# + if
# + etc...
#
# Another new thing we will encounter in the code below is a Lemmatizer. A lematizer rests on the lemmatization process which essentially extracts the root of the word and removes any additional artifacts. A more formal definition is provided below:
#
# <span style='color:red'>Lemmatization usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma. </span>
#
# **Note**: If unclear about the implementation of the methods please consult the NLTK documentation.

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

# Create a set of stopwords
stop = set(stopwords.words('english'))

# Create a set of punctuation words 
exclude = set(string.punctuation) 

# This is the function makeing the lemmatization
lemma = WordNetLemmatizer()

# In this function we perform the entire cleaning
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# This is the clean corpus.
doc_clean = [clean(doc).split() for doc in doc_complete]

# %% [markdown]
# ### Preparing Document-Term Matrix
#
# All the text documents combined is known as the corpus. To run any mathematical model on text corpus, it is a good practice to convert it into a matrix representation. LDA model looks for repeating term patterns in the entire DT matrix. Python provides many great libraries for text mining practices, “gensim” is one such clean and beautiful library to handle text data. It is scalable, robust and efficient.
#
# Following code shows how to convert a corpus into a document-term matrix.

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our courpus, where every unique term is assigned an index
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %% [markdown]
# ### Run the LDA model
#
# Next step is to create an object for LDA model and train it on Document-Term matrix. The training also requires few parameters as input which are explained in the above section. The gensim module allows both LDA model estimation from a training corpus and inference of topic distribution on new, unseen documents.
#
#
# In the code below we are running the LDA model on two topics with the words we have defined in our dictionary for 100 itterations. Feel free to change the number of itterations and see the outcome.

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=2, id2word = dictionary, passes=100)

# %% [markdown]
# Each line is a topic with individual topic terms and weights. Topic1 can be termed as Vehicles and Engines, and Topic 2 can be termed as Benefits of Fitness.

# %%
# Print 2 topics and describe then with 4 words.
topics = ldamodel.print_topics(num_topics=2, num_words=4)

i=0
for topic in topics:
    print ("Topic",i ,"->", topic)     
    i+=1

# %% [markdown]
# We notice that our LDA model performed well in guessing the two topics our documents covered.

# %% [markdown]
# ## Assignment
# ### This assignment should result in a report following the report guidelines found on Canvas. The full details of the assignment are also found on Canvas.
# ### Due date: <b style='color: red'>  25/09/20, 23:59:59 </b>

# %% [markdown]
# So far we have covered the following sections:
#
# + Basic Python development
# + Pandas data management
# + Gathering data (scraping the Twitter Streaming API)
# + Storing and organizing it (store to file or a database)
# + Preprocessing the data
# + Performing sentiment and topical analysis
# + Visualizing insight
#
# Given the newly acquired skills, your assignment is to perform an analysis on a dataset of tweets already provided in the course. The analysis should contain sentiment analysis and try to include topic modelling. Use different splits of the data you have to perform your analysis, compare, correlate and visualize.
#
# The dataset can be found on Canvas in the "2020_Assignments" folder.
#
# All of the tweets have geolocation on them so it would be natural to show the geographical distribution of the analysis you performed on the map you designed in Week 2 of the course. When visualising the results of your analysis keep in mind that you can change the size, color, location or even boundries of the map. You can also hide and show regions depending on what is the point you are trying to make.
#
# Two ideas to try to correlate the findings with:
#
# + Demographics - e.g. average stage age
# + Past State vote percentage difference
#
# This information can be obtained from the sources mentioned in the lectures.
#
# As an additional possible resource to help with the sentiment analysis, there is a Java based utility in the same folder named SentiStrenght.
#
# [Sentistrength (Free download version)](http://sentistrength.wlv.ac.uk/#Download)
